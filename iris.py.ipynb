# %%
# Simple classifier of flowers

import sklearn
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
 
iris = load_iris() #load the iris data set
iris_keys = iris.keys() #get keys of the dataset

#x_train and x_test contain 75% data and 25% respectively, y contains the labels
x_train, x_test, y_train, y_test = train_test_split(iris['data'], iris['target'], random_state=0)


x_train.shape #prints (a,b) with a being number of samples and b the number of features
x_test.shape

#print(iris['data'][:5])
# Out:
# (38, 4)

# %%
# fig, ax = plt.subplots(3, 3, figsize=(15, 15))
# plt.suptitle("iris_pairplot")
# for i in range(3):
#     for j in range(3):
#         ax[i, j].scatter(x_train[:, j], x_train[:, i + 1], c=y_train, s=60)
#         ax[i, j].set_xticks(())
#         ax[i, j].set_yticks(())
#     if i == 2:
#         ax[i, j].set_xlabel(iris['feature_names'][j])
#     if j == 0:
#         ax[i, j].set_ylabel(iris['feature_names'][i + 1])
#     if j > i:
#         ax[i, j].set_visible(False)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression()
lr.fit(x_train, y_train)

knn = KNeighborsClassifier(n_neighbors=1) #set 1 neighbor for the classifier model
knn.fit(x_train, y_train) #set the data and labels for training into the algorithm
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=1, p=2,
#                      weights='uniform')

# %%
pred = knn.predict(x_test) #manually calculating the score
np.mean(pred == y_test)
# Out:
# 0.9736842105263158

# %%
knn.score(x_test,y_test) #get the accuracy of the score using object of knn
# Out:
# 0.9736842105263158

# %%
new_dataset = np.loadtxt("first_iris.csv")
new_dataset
# Out:
# array([[5.06348571, 3.36500942, 1.54881089, 0.25824064],
#        [4.86774069, 3.31296578, 1.37589479, 0.2056251 ],
#        [4.63277729, 3.18322882, 1.35519156, 0.22834351],
#        [5.0432363 , 3.54141129, 1.02596721, 0.02073456],
#        [4.96435204, 3.37515635, 1.35983482, 0.18499077],
#        [5.3085985 , 3.46646222, 1.6645459 , 0.2778045 ],
#        [4.61873563, 3.17097032, 1.36646944, 0.23545288],
#        [4.96530236, 3.33803895, 1.46448392, 0.23295492],
#        [4.43406562, 3.05841704, 1.37960494, 0.26682342],
#        [4.87043243, 3.27989636, 1.47212356, 0.24948055],
#        [5.34243265, 3.45678799, 1.74629679, 0.31073398],
#        [4.79686942, 3.20376998, 1.56427862, 0.30192473],
#        [4.77797921, 3.26065811, 1.37561135, 0.21780867],
#        [4.66424676, 3.34077022, 0.96968201, 0.04703877],
#        [5.37035429, 3.45353983, 1.80060709, 0.33186345],
#        [5.34828334, 3.4579737 , 1.75249253, 0.31277879],
#        [5.20193215, 3.49912765, 1.40079856, 0.17122469],
#        [5.0524107 , 3.42551906, 1.36275928, 0.17425456],
#        [5.95757975, 3.28924499, 3.20944443, 0.89877751],
#        [7.11847849, 2.93598917, 6.07365784, 2.05585298],
#        [6.82322794, 3.0464184 , 5.28801922, 1.73529366],
#        [6.38567078, 2.79944882, 5.26437885, 1.78445482],
#        [6.751803  , 2.94448566, 5.4553291 , 1.8219841 ],
#        [5.76780315, 2.54338292, 4.97355379, 1.7355592 ],
#        [5.87713012, 2.57365881, 5.06677299, 1.76340289],
#        [6.40765297, 2.81632136, 5.25316278, 1.77628454],
#        [6.48251857, 2.78756263, 5.4544788 , 1.85853479],
#        [7.43770873, 2.84329772, 6.84891669, 2.36835236],
#        [7.49226794, 2.82732424, 6.98178101, 2.42192935],
#        [5.96758096, 2.63738633, 5.03645159, 1.73705942],
#        [6.85704905, 2.93601528, 5.64956185, 1.89681131],
#        [5.58602326, 3.3960009 , 2.310246  , 0.53649644],
#        [7.38006607, 2.85946768, 6.7105054 , 2.31264909],
#        [6.27848548, 2.88005099, 4.86662722, 1.61636065],
#        [6.67922891, 2.83334489, 5.64635396, 1.91973108],
#        [7.08351613, 2.94625893, 5.98842275, 2.02147701],
#        [6.18943788, 2.86470267, 4.76483297, 1.58179406],
#        [6.11080502, 2.78484439, 4.8591318 , 1.63591896],
#        [6.40717552, 2.70528524, 5.5608335 , 1.91774901],
#        [7.02331948, 2.96445364, 5.84024449, 1.96163541],
#        [6.4793939 , 2.54069196, 6.13518811, 2.17180306],
#        [7.4117377 , 2.85333297, 6.77891647, 2.33974454],
#        [6.86624906, 3.03343043, 5.39387604, 1.77804142],
#        [6.27879912, 2.81018026, 5.06122852, 1.70575227],
#        [6.40978417, 3.16256705, 4.29479014, 1.33554435],
#        [7.26799192, 2.89573971, 6.42796821, 2.19817572],
#        [6.8369977 , 3.04144527, 5.32416774, 1.75001777],
#        [6.68980417, 2.90793141, 5.45631394, 1.83094195],
#        [6.02005462, 2.7675511 , 4.75997858, 1.60279972],
#        [6.82695403, 3.02119703, 5.36412469, 1.76975897],
#        [7.09551995, 2.96943597, 5.94350918, 1.99918895],
#        [6.74563867, 3.04605411, 5.16318585, 1.68856688],
#        [6.40823218, 3.16141377, 4.29547657, 1.33607272],
#        [6.77936651, 2.81903959, 5.84850978, 1.99890037],
#        [6.69269702, 2.84049259, 5.648343  , 1.91879759],
#        [6.65907473, 2.99722115, 5.15843629, 1.69825925],
#        [6.07870674, 2.72375658, 4.9767649 , 1.69438402],
#        [6.47618475, 2.89081887, 5.15737217, 1.72285975],
#        [6.24262566, 2.68594233, 5.34767544, 1.84235964],
#        [5.94672804, 2.61734796, 5.05829356, 1.74995821]])

# %%
test_classifier = KNeighborsClassifier(n_neighbors=1)

x_train, x_test, y_train, y_test = train_test_split(new_dataset, iris['target'], random_state=0)

# %%
test_classifier.fit(x_train, y_train)

test_classifier.score(x_test, y_test)
# Out:
# 0.8947368421052632
