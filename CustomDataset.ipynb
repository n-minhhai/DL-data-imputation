# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import numpy as np
import pandas as pd
import sklearn
import random
import sys
import os
import matplotlib.pyplot as plt
import math
import scipy
from distcorr import distcorr
from fractions import gcd
from scipy.stats import pearsonr
from sklearn import preprocessing
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

# %%
x = []

for i in np.arange(1,5,0.01):
    x = np.append(x, i)

y = 3**x
y2 = 3.5**x
y3 = 4**x
y4 = 4.5**x
y5 = 5**x

print(len(x))

dataset = np.vstack((x, y, y2, y3, y4, y5)).T
# plt.plot(x,y)
# plt.plot(x,y2)
# plt.plot(x,y3)
# plt.plot(x,y4)
# plt.plot(x,y5)
plt.plot(dataset[:, 0], dataset[:, 1:])
# Out:
# 400
# [<matplotlib.lines.Line2D at 0x28d5b5ce1d0>,
#  <matplotlib.lines.Line2D at 0x28d5b5ce2e8>,
#  <matplotlib.lines.Line2D at 0x28d5b5ce438>,
#  <matplotlib.lines.Line2D at 0x28d5b5ce588>,
#  <matplotlib.lines.Line2D at 0x28d5b5ce6d8>]

# %%
corr = distcorr(x, y5)
corr
# Out:
# 0.873351092741353

# %%
pearson, _ = pearsonr(x, y5)
pearson
# Out:
# 0.8034043065285785

# %%
dataset
# Out:
# array([[   1.  ,    3.  ,    3.5 ,    4.  ,    4.5 ,    5.  ],
#        [   1.01,    3.03,    3.54,    4.06,    4.57,    5.08],
#        [   1.02,    3.07,    3.59,    4.11,    4.64,    5.16],
#        ...,
#        [   4.97,  235.12,  505.85,  982.29, 1763.87, 2977.7 ],
#        [   4.98,  237.72,  512.22,  996.  , 1790.6 , 3026.01],
#        [   4.99,  240.34,  518.68, 1009.9 , 1817.73, 3075.11]])

# %%
noise_value = 3

np.random.seed(0)
noise = np.absolute(np.random.normal(0, noise_value**2, x.shape))
noise2 = np.absolute(np.random.normal(0, noise_value**2.5, x.shape))
noise3 = np.absolute(np.random.normal(0, noise_value**3, x.shape))
noise4 = np.absolute(np.random.normal(0, noise_value**3.5, x.shape))
noise5 = np.absolute(np.random.normal(0, noise_value**4, x.shape))

y_noise = y + noise
y_noise2 = y2 + noise2
y_noise3 = y3 + noise3
y_noise4 = y4 + noise4
y_noise5 = y5 + noise5

# %%
noised_dataset = np.vstack((x, y_noise, y_noise2, y_noise3, y_noise4, y_noise5)).T
plt.plot(noised_dataset[:, 0], noised_dataset[:, 1:])
# Out:
# [<matplotlib.lines.Line2D at 0x1e7e72a10f0>,
#  <matplotlib.lines.Line2D at 0x1e7e72a1208>,
#  <matplotlib.lines.Line2D at 0x1e7e72a1358>,
#  <matplotlib.lines.Line2D at 0x1e7e72a14a8>,
#  <matplotlib.lines.Line2D at 0x1e7e72a15f8>]

# %%
noised_dataset
# Out:
# array([[   1.  ,   18.88,   12.83,   42.1 ,   46.42,   39.89],
#        [   1.01,    6.63,   20.94,   25.27,   96.36,   17.22],
#        [   1.02,   11.88,   15.54,    5.66,   78.75,   86.65],
#        ...,
#        [   4.97,  245.39,  522.64,  998.32, 1829.91, 2990.53],
#        [   4.98,  250.92,  518.84, 1050.32, 1855.16, 3118.51],
#        [   4.99,  248.02,  531.62, 1025.82, 1842.8 , 3181.3 ]])

# %%
NAN = 0

def fill_nan(array, REPLACE_COUNT):
    array.flat[np.random.choice(array.size, int(REPLACE_COUNT), replace=False)] = NAN

    return array

# %%
full_data = noised_dataset.copy()
missing_data = fill_nan(noised_dataset, noised_dataset.size*0.2)

# %%
full_data
# Out:
# array([[   1.  ,   18.88,   12.83,   42.1 ,   46.42,   39.89],
#        [   1.01,    6.63,   20.94,   25.27,   96.36,   17.22],
#        [   1.02,   11.88,   15.54,    5.66,   78.75,   86.65],
#        ...,
#        [   4.97,  245.39,  522.64,  998.32, 1829.91, 2990.53],
#        [   4.98,  250.92,  518.84, 1050.32, 1855.16, 3118.51],
#        [   4.99,  248.02,  531.62, 1025.82, 1842.8 , 3181.3 ]])

# %%
bins = np.linspace(0, 10)
y_binned = np.digitize(full_data[:,0], bins)

# %%
np.set_printoptions(precision=2, suppress=True)
missing_data
# Out:
# array([[   1.  ,    0.  ,   12.83,   42.1 ,   46.42,   39.89],
#        [   0.  ,    6.63,   20.94,   25.27,   96.36,   17.22],
#        [   1.02,   11.88,    0.  ,    0.  ,   78.75,   86.65],
#        ...,
#        [   4.97,  245.39,  522.64,  998.32,    0.  ,    0.  ],
#        [   4.98,  250.92,  518.84, 1050.32, 1855.16, 3118.51],
#        [   4.99,    0.  ,  531.62, 1025.82, 1842.8 ,    0.  ]])

# %%
x_train, x_test, y_train, y_test = train_test_split(missing_data, full_data, stratify=y_binned, random_state=0)
x_train
# Out:
# array([[  3.23,   0.  ,  61.9 ,   0.  , 135.23,   0.  ],
#        [  2.89,  37.81,   0.  ,  63.13,   0.  , 254.14],
#        [  3.  ,  30.32,  67.04,  79.01, 113.07, 191.26],
#        ...,
#        [  0.  ,  83.85, 133.73, 209.86, 277.83, 412.03],
#        [  1.19,   0.  ,  31.25,   5.83,  29.39,   0.  ],
#        [  0.  ,  42.41,  46.89,  79.31, 139.49, 106.  ]])

# %%
NUM_EPOCHS = 110
LEARNING_RATE = 0.001
BATCH_SIZE = -1
NUM_FEATURES = 6
BATCH_SIZE_TEST = -1

# %%
x_train = torch.from_numpy(x_train)
#x_train = x_train.to(device)
x_train = x_train.view(BATCH_SIZE, NUM_FEATURES)

y_train = torch.from_numpy(y_train)
#y_train = y_train.to(device)
y_train = y_train.view(BATCH_SIZE, NUM_FEATURES)

x_test = torch.from_numpy(x_test)
#x_test = x_test.to(device)
x_test = x_test.view(BATCH_SIZE_TEST, NUM_FEATURES)

y_test = torch.from_numpy(y_test)
#y_test = y_test.to(device)
y_test = y_test.view(BATCH_SIZE_TEST, NUM_FEATURES)

x_train.shape
# Out:
# torch.Size([300, 6])

# %%
class Autoencoder(nn.Module):
    def __init__(self):
        super(Autoencoder, self).__init__()

        self.enc1 = nn.Linear(in_features=6, out_features=8)
        self.enc2 = nn.Linear(in_features=8, out_features=16)

        self.dec2 = nn.Linear(in_features=16, out_features=8)
        self.dec3 = nn.Linear(in_features=8, out_features=6)

    def forward(self, x):
        x = F.leaky_relu(self.enc1(x))
        x = F.leaky_relu(self.enc2(x))
        x = F.leaky_relu(self.dec2(x))
        x = self.dec3(x)
        return x

# %%
# CREATE A SEED FOR CONSISTENT WEIGHT INITIALIZATIONS - FOR TESTING PURPOSES
random.seed(1)
torch.manual_seed(random.randint(1, 10))
net = Autoencoder().double()
#net.to(device)

# %%
criterion = nn.MSELoss()
optimizer = optim.Adam(net.parameters(), lr=LEARNING_RATE)

# %%
def train(net):
    train_loss = []
    torch.set_printoptions(precision=2, sci_mode=False)
    np.set_printoptions(precision=2, suppress=True)

    for epoch in range(NUM_EPOCHS):
        # running_loss: LOSS OF THE PREDICTED MISSING VALUE ONLY
        # overall_loss: LOSS OF ALL RECONSTRUCTED VALUES

        running_loss = 0.0
        overall_loss = 0.0
        count = 0
        for missing_data, full_data in zip(x_train, y_train):
            optimizer.zero_grad()
            outputs = net(missing_data.double())

            # LEARN FROM LOSS OF ALL RECONSTRUCTED VALUES
            loss = criterion(outputs, full_data)
            loss.backward()
            optimizer.step()
            overall_loss += loss.item()
            
            # COMPUTE LOSS OF PREDICTED MISSING VALUE
            if NAN in missing_data:
                for index in range(len(missing_data)):
                    if missing_data[index] == NAN:
                        predicted_loss = criterion(outputs[index], full_data[index])
                        running_loss += predicted_loss.item()
                        count += 1
            
            # PRINT ALL VALUES ON LAST EPOCH FOR TESTING PURPOSES
            if epoch == NUM_EPOCHS-1:
                if missing_data.detach().numpy().all() == full_data.detach().numpy().all():
                    print("Input: ", missing_data)
                    print("Target: ", full_data)
                    print("Outputs: ", outputs)
                else:
                    print("Input (missing): ", missing_data)
                    print("Target (missing): ", full_data)
                    print("Outputs (missing): ", outputs)
        
      #  loss = running_loss / count
        overall_loss = overall_loss / len(x_train)
        train_loss.append(loss)

        print('Epoch {} of {}, Train Loss: {:.5f}, Overall: {:.5f}'
             .format(epoch+1, NUM_EPOCHS, loss, overall_loss))

    return train_loss


def test(net):

    net.eval()
    count = 0

    with torch.no_grad():
        test_loss = []
        running_loss = 0.0

        for missing_data, full_data in zip(x_test, y_test):
            outputs = net(missing_data.double())
            if NAN in missing_data:
                for index in range(len(missing_data)):
                    if missing_data[index] == NAN:
                        predicted_loss = criterion(outputs[index], full_data[index])
                        running_loss += predicted_loss.item()
                        count += 1
            
            if missing_data.detach().numpy().all() == full_data.detach().numpy().all():
                print("Input: ", missing_data)
                print("Target: ", full_data)
                print("Outputs: ", outputs)
            else:
                print("Input (missing): ", missing_data)
                print("Target (missing): ", full_data)
                print("Outputs (missing): ", outputs)

        loss = running_loss / count
        test_loss.append(loss)
        print('Test Loss: {:.3f}'.format(loss))

        return test_loss

# %%
# TRAIN THE NEURAL NETWORK
results = train(net)
# Out:
# 35, 214.41, 298.27, 471.47], dtype=torch.float64)
# Target (missing):  tensor([  3.77,  63.96, 128.35, 214.41, 298.27, 471.47], dtype=torch.float64)
# Outputs (missing):  tensor([  3.46,  53.68, 100.56, 178.61, 302.05, 483.11], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([  0.00,  42.40,  65.05, 102.08,   0.00,   0.00], dtype=torch.float64)
# Target (missing):  tensor([  3.31,  42.40,  65.05, 102.08, 263.79, 290.97], dtype=torch.float64)
# Outputs (missing):  tensor([  2.95,  40.85,  72.73, 127.37, 214.33, 314.04], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([  2.52,  22.64,   0.00,  70.74,   0.00, 133.40], dtype=torch.float64)
# Target (missing):  tensor([  2.52,  22.64,  38.19,  70.74,  69.53, 133.40], dtype=torch.float64)
# Outputs (missing):  tensor([  2.56,  21.88,  33.60,  52.57,  84.41, 133.98], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input:  tensor([  3.97,  83.62, 156.91, 247.34, 403.51, 729.03], dtype=torch.float64)
# Target:  tensor([  3.97,  83.62, 156.91, 247.34, 403.51, 729.03], dtype=torch.float64)
# Outputs:  tensor([  4.21,  75.04, 144.54, 265.54, 456.36, 749.37], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input:  tensor([  1.40,  14.09,  11.94,  13.43, 116.75,  22.95], dtype=torch.float64)
# Target:  tensor([  1.40,  14.09,  11.94,  13.43, 116.75,  22.95], dtype=torch.float64)
# Outputs:  tensor([ 2.39, 21.07, 31.05, 45.54, 68.17, 89.32], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([ 1.92, 10.12,  0.00,  0.00, 25.47,  0.00], dtype=torch.float64)
# Target (missing):  tensor([  1.92,  10.12,  28.23,  39.44,  25.47, 196.38], dtype=torch.float64)
# Outputs (missing):  tensor([ 2.25, 13.93, 16.34, 19.10, 24.29, 30.20], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([ 1.35,  5.81, 10.33, 29.91,  0.00, 29.25], dtype=torch.float64)
# Target (missing):  tensor([ 1.35,  5.81, 10.33, 29.91, 81.63, 29.25], dtype=torch.float64)
# Outputs (missing):  tensor([ 2.32, 15.41, 19.73, 24.56, 33.44, 41.77], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([  3.15,   0.00,  58.05, 103.29,   0.00, 276.33], dtype=torch.float64)
# Target (missing):  tensor([  3.15,  35.53,  58.05, 103.29, 195.76, 276.33], dtype=torch.float64)
# Outputs (missing):  tensor([  3.00,  34.68,  60.18, 103.41, 173.82, 282.45], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([  3.63,   0.00,  95.92, 155.66,   0.00, 436.44], dtype=torch.float64)
# Target (missing):  tensor([  3.63,  54.42,  95.92, 155.66, 253.31, 436.44], dtype=torch.float64)
# Outputs (missing):  tensor([  3.47,  48.80,  89.64, 159.95, 273.47, 447.69], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input:  tensor([  3.13,  35.34,  64.42, 118.85, 144.54, 213.25], dtype=torch.float64)
# Target:  tensor([  3.13,  35.34,  64.42, 118.85, 144.54, 213.25], dtype=torch.float64)
# Outputs:  tensor([  2.83,  35.52,  61.20,  97.98, 154.95, 213.65], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([ 2.57,  0.00, 25.34,  0.00, 66.59, 64.54], dtype=torch.float64)
# Target (missing):  tensor([ 2.57, 26.55, 25.34, 56.99, 66.59, 64.54], dtype=torch.float64)
# Outputs (missing):  tensor([ 2.39, 19.61, 28.26, 37.98, 53.48, 60.72], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input:  tensor([   4.36,  136.10,  244.37,  427.54,  780.43, 1153.46],
#        dtype=torch.float64)
# Target:  tensor([   4.36,  136.10,  244.37,  427.54,  780.43, 1153.46],
#        dtype=torch.float64)
# Outputs:  tensor([   5.59,  123.17,  241.69,  438.01,  742.22, 1177.44],
#        dtype=torch.float64, grad_fn=<AddBackward0>)
# Input (missing):  tensor([ 1.18,  0.00, 28.08,  0.00,  0.00, 88.38], dtype=torch.float64)
# Target (missing):  tensor([ 1.18,  6.47, 28.08, 28.15, 61.78, 88.38], dtype=torch.float64)
# Outputs (missing):  tensor([ 2.45, 18.34, 25.80, 37.14, 56.83, 88.63], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([ 2.75, 26.65, 37.02,  0.00, 98.80,  0.00], dtype=torch.float64)
# Target (missing):  tensor([  2.75,  26.65,  37.02,  53.54,  98.80, 155.43], dtype=torch.float64)
# Outputs (missing):  tensor([  2.45,  23.80,  35.83,  58.43,  93.89, 148.19], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([ 1.95, 14.88,  0.00, 68.87,  0.00, 76.31], dtype=torch.float64)
# Target (missing):  tensor([ 1.95, 14.88, 12.66, 68.87, 45.05, 76.31], dtype=torch.float64)
# Outputs (missing):  tensor([ 2.43, 18.85, 26.51, 38.77, 59.68, 92.68], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([  0.00,  18.08,  39.31,  63.29,  77.85, 121.13], dtype=torch.float64)
# Target (missing):  tensor([  2.41,  18.08,  39.31,  63.29,  77.85, 121.13], dtype=torch.float64)
# Outputs (missing):  tensor([  2.49,  24.88,  38.83,  57.51,  86.97, 113.58], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input:  tensor([ 1.57,  8.33, 41.47, 19.78, 64.47, 86.29], dtype=torch.float64)
# Target:  tensor([ 1.57,  8.33, 41.47, 19.78, 64.47, 86.29], dtype=torch.float64)
# Outputs:  tensor([ 2.40, 21.45, 31.77, 44.80, 65.59, 82.06], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([  3.65,   0.00, 106.92, 167.88, 272.89, 379.40], dtype=torch.float64)
# Target (missing):  tensor([  3.65,  56.84, 106.92, 167.88, 272.89, 379.40], dtype=torch.float64)
# Outputs (missing):  tensor([  3.10,  52.02,  93.92, 158.31, 258.30, 377.50], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([  1.41,   0.00,  23.92,  17.05,  13.81, 117.33], dtype=torch.float64)
# Target (missing):  tensor([  1.41,  17.49,  23.92,  17.05,  13.81, 117.33], dtype=torch.float64)
# Outputs (missing):  tensor([  2.47,  20.98,  30.96,  46.87,  73.92, 116.72], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([ 0.00, 16.00, 11.15, 44.88, 38.00, 77.07], dtype=torch.float64)
# Target (missing):  tensor([ 1.53, 16.00, 11.15, 44.88, 38.00, 77.07], dtype=torch.float64)
# Outputs (missing):  tensor([ 2.35, 18.80, 26.29, 35.91, 51.90, 68.43], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([  2.76,  27.97,  44.30,   0.00, 148.07, 174.35], dtype=torch.float64)
# Target (missing):  tensor([  2.76,  27.97,  44.30,  56.86, 148.07, 174.35], dtype=torch.float64)
# Outputs (missing):  tensor([  2.58,  30.24,  49.44,  77.70, 122.26, 173.69], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([  3.92,  94.92,   0.00,   0.00, 390.02, 578.40], dtype=torch.float64)
# Target (missing):  tensor([  3.92,  94.92, 159.17, 273.37, 390.02, 578.40], dtype=torch.float64)
# Outputs (missing):  tensor([  3.42,  63.47, 116.67, 209.31, 356.94, 584.76], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input:  tensor([  2.73,  25.93,  42.54,  81.52, 135.00, 153.54], dtype=torch.float64)
# Target:  tensor([  2.73,  25.93,  42.54,  81.52, 135.00, 153.54], dtype=torch.float64)
# Outputs:  tensor([  2.53,  32.75,  54.61,  82.45, 125.08, 147.57], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([  3.98,  82.83,   0.00, 258.40,   0.00,   0.00], dtype=torch.float64)
# Target (missing):  tensor([  3.98,  82.83, 149.44, 258.40, 448.39, 629.40], dtype=torch.float64)
# Outputs (missing):  tensor([  3.55,  80.52, 152.05, 269.86, 458.51, 659.79], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([  3.93,  84.54, 165.17, 252.12,   0.00,   0.00], dtype=torch.float64)
# Target (missing):  tensor([  3.93,  84.54, 165.17, 252.12, 391.35, 602.61], dtype=torch.float64)
# Outputs (missing):  tensor([  3.58,  88.92, 165.54, 302.42, 518.23, 771.03], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input:  tensor([ 2.50, 16.20, 25.47, 57.58, 85.96, 62.91], dtype=torch.float64)
# Target:  tensor([ 2.50, 16.20, 25.47, 57.58, 85.96, 62.91], dtype=torch.float64)
# Outputs:  tensor([ 2.34, 25.21, 39.36, 52.93, 73.07, 56.55], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input:  tensor([ 2.10, 26.85, 27.84, 40.45, 51.72, 86.00], dtype=torch.float64)
# Target:  tensor([ 2.10, 26.85, 27.84, 40.45, 51.72, 86.00], dtype=torch.float64)
# Outputs:  tensor([ 2.38, 21.57, 31.74, 44.60, 65.29, 81.73], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([ 0.00, 17.53, 11.25, 20.87,  0.00,  0.00], dtype=torch.float64)
# Target (missing):  tensor([  1.88,  17.53,  11.25,  20.87,  21.55, 118.61], dtype=torch.float64)
# Outputs (missing):  tensor([ 2.32, 18.77, 26.16, 35.10, 50.20, 56.10], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([ 1.59,  9.00,  8.12,  9.75, 31.90,  0.00], dtype=torch.float64)
# Target (missing):  tensor([ 1.59,  9.00,  8.12,  9.75, 31.90, 40.13], dtype=torch.float64)
# Outputs (missing):  tensor([ 2.24, 14.92, 18.15, 22.07, 29.25, 36.86], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([   0.00,  200.71,  422.09,  787.28, 1428.26, 2301.79],
#        dtype=torch.float64)
# Target (missing):  tensor([   4.81,  200.71,  422.09,  787.28, 1428.26, 2301.79],
#        dtype=torch.float64)
# Outputs (missing):  tensor([   7.34,  226.97,  441.83,  816.36, 1406.84, 2318.52],
#        dtype=torch.float64, grad_fn=<AddBackward0>)
# Input (missing):  tensor([  2.66,   0.00,  33.53,  40.28,  76.05, 153.43], dtype=torch.float64)
# Target (missing):  tensor([  2.66,  27.59,  33.53,  40.28,  76.05, 153.43], dtype=torch.float64)
# Outputs (missing):  tensor([  2.46,  24.65,  37.90,  59.49,  95.30, 151.80], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([ 0.00, 19.57, 32.48, 34.70, 65.14, 70.90], dtype=torch.float64)
# Target (missing):  tensor([ 2.49, 19.57, 32.48, 34.70, 65.14, 70.90], dtype=torch.float64)
# Outputs (missing):  tensor([ 2.29, 22.39, 33.62, 45.24, 63.38, 60.94], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([  1.28,  17.88,   0.00,  42.91,  42.23, 114.19], dtype=torch.float64)
# Target (missing):  tensor([  1.28,  17.88,  13.85,  42.91,  42.23, 114.19], dtype=torch.float64)
# Outputs (missing):  tensor([  2.30,  20.60,  29.97,  44.58,  69.63, 109.28], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input:  tensor([  1.90,  11.69,  26.86,  31.40,  40.91, 151.27], dtype=torch.float64)
# Target:  tensor([  1.90,  11.69,  26.86,  31.40,  40.91, 151.27], dtype=torch.float64)
# Outputs:  tensor([  2.30,  24.07,  37.21,  58.31,  94.15, 149.74], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([ 2.82, 27.95, 51.99,  0.00,  0.00,  0.00], dtype=torch.float64)
# Target (missing):  tensor([  2.82,  27.95,  51.99,  59.63, 110.91, 225.29], dtype=torch.float64)
# Outputs (missing):  tensor([ 2.16, 17.89, 24.11, 33.26, 48.68, 63.66], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input:  tensor([   4.42,  134.68,  281.33,  499.26,  812.26, 1265.65],
#        dtype=torch.float64)
# Target:  tensor([   4.42,  134.68,  281.33,  499.26,  812.26, 1265.65],
#        dtype=torch.float64)
# Outputs:  tensor([   2.33,  134.40,  262.29,  470.62,  802.64, 1259.77],
#        dtype=torch.float64, grad_fn=<AddBackward0>)
# Input (missing):  tensor([  2.99,  38.73,  45.13,   0.00, 109.47, 145.10], dtype=torch.float64)
# Target (missing): tensor([  2.99,  38.73,  45.13,  72.79, 109.47, 145.10], dtype=torch.float64)
# Outputs (missing):  tensor([  2.19,  26.57,  42.34,  64.84, 101.53, 144.08], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([   0.00,  204.18,  437.26,  871.39, 1495.88,    0.00],
#        dtype=torch.float64)
# Target (missing):  tensor([   4.84,  204.18,  437.26,  871.39, 1495.88, 2463.99],
#        dtype=torch.float64)
# Outputs (missing):  tensor([    2.32,   217.10,   450.34,   842.50,  1497.81,  2479.83],
#        dtype=torch.float64, grad_fn=<AddBackward0>)
# Input:  tensor([  3.34,  49.63,  72.72, 122.89, 174.42, 246.04], dtype=torch.float64)
# Target:  tensor([  3.34,  49.63,  72.72, 122.89, 174.42, 246.04], dtype=torch.float64)
# Outputs:  tensor([  2.33,  40.22,  70.79, 113.09, 179.59, 239.45], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([ 2.70, 27.71,  0.00, 59.99,  0.00,  0.00], dtype=torch.float64)
# Target (missing):  tensor([ 2.70, 27.71, 36.52, 59.99, 94.08, 94.56], dtype=torch.float64)
# Outputs (missing):  tensor([  2.33,  26.58,  43.12,  65.76, 103.04, 128.65], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input:  tensor([ 2.34, 18.80, 38.70, 34.06, 62.42, 54.70], dtype=torch.float64)
# Target:  tensor([ 2.34, 18.80, 38.70, 34.06, 62.42, 54.70], dtype=torch.float64)
# Outputs:  tensor([ 2.30, 22.14, 33.61, 44.25, 60.46, 48.53], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([  1.06,  11.76,  16.47,   0.00,  45.66, 107.61], dtype=torch.float64)
# Target (missing):  tensor([  1.06,  11.76,  16.47,  17.79,  45.66, 107.61], dtype=torch.float64)
# Outputs (missing):  tensor([  2.38,  19.76,  28.94,  43.01,  66.90, 104.51], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input:  tensor([ 2.56, 26.79, 61.56, 58.09, 66.29, 89.25], dtype=torch.float64)
# Target:  tensor([ 2.56, 26.79, 61.56, 58.09, 66.29, 89.25], dtype=torch.float64)
# Outputs:  tensor([ 2.42, 24.92, 39.50, 55.82, 80.80, 83.81], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([ 1.36, 15.53, 18.30,  0.00, 52.65, 79.30], dtype=torch.float64)
# Target (missing):  tensor([ 1.36, 15.53, 18.30, 29.49, 52.65, 79.30], dtype=torch.float64)
# Outputs (missing):  tensor([ 2.37, 18.44, 26.09, 36.33, 53.34, 73.87], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([  3.46,  55.13,  92.33,   0.00, 322.06, 284.05], dtype=torch.float64)
# Target (missing):  tensor([  3.46,  55.13,  92.33, 132.86, 322.06, 284.05], dtype=torch.float64)
# Outputs (missing):  tensor([  3.08,  50.39,  93.00, 148.39, 231.27, 276.78], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([   4.65,  166.88,    0.00,    0.00,    0.00, 1905.82],
#        dtype=torch.float64)
# Target (missing):  tensor([   4.65,  166.88,  355.97,  639.18, 1094.52, 1905.82],
#        dtype=torch.float64)
# Outputs (missing):  tensor([   7.79,  171.25,  354.46,  669.89, 1174.39, 1927.49],
#        dtype=torch.float64, grad_fn=<AddBackward0>)
# Input (missing):  tensor([ 0.00, 27.10, 46.18,  0.00,  0.00,  0.00], dtype=torch.float64)
# Target (missing):  tensor([  2.95,  27.10,  46.18,  70.86, 128.90, 160.37], dtype=torch.float64)
# Outputs (missing):  tensor([ 2.31, 17.02, 22.83, 31.50, 45.70, 60.36], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([ 1.71,  0.00, 16.93,  0.00, 78.81, 97.81], dtype=torch.float64)
# Target (missing):  tensor([ 1.71,  7.71, 16.93, 27.75, 78.81, 97.81], dtype=torch.float64)
# Outputs (missing):  tensor([ 2.42, 20.28, 30.18, 43.55, 65.16, 90.28], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([ 0.00,  7.33,  6.92,  0.00, 59.47, 86.82], dtype=torch.float64)
# Target (missing):  tensor([ 1.39,  7.33,  6.92, 15.28, 59.47, 86.82], dtype=torch.float64)
# Outputs (missing):  tensor([ 2.37, 18.26, 26.00, 36.55, 54.11, 77.74], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input:  tensor([  2.31,  17.50,  24.32,  31.57,  68.50, 156.71], dtype=torch.float64)
# Target:  tensor([  2.31,  17.50,  24.32,  31.57,  68.50, 156.71], dtype=torch.float64)
# Outputs:  tensor([  2.49,  23.61,  37.72,  59.88,  96.00, 152.81], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([ 1.16, 17.02,  0.00, 23.02, 40.89,  0.00], dtype=torch.float64)
# Target (missing):  tensor([ 1.16, 17.02, 10.06, 23.02, 40.89, 24.88], dtype=torch.float64)
# Outputs (missing):  tensor([ 2.26, 15.63, 20.43, 26.31, 36.58, 47.49], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([   4.74,  183.07,  384.90,    0.00, 1335.33,    0.00],
#        dtype=torch.float64)
# Target (missing):  tensor([   4.74,  183.07,  384.90,  763.30, 1335.33, 2083.49],
#        dtype=torch.float64)
# Outputs (missing):  tensor([   4.19,  185.95,  384.90,  749.04, 1311.85, 2150.23],
#        dtype=torch.float64, grad_fn=<AddBackward0>)
# Input (missing):  tensor([  2.91,   0.00,  45.15,   0.00, 103.31, 157.47], dtype=torch.float64)
# Target (missing):  tensor([  2.91,  26.86,  45.15,  61.32, 103.31, 157.47], dtype=torch.float64)
# Outputs (missing):  tensor([  2.43,  23.97,  38.61,  61.20,  97.63, 154.00], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([  4.26,   0.00, 222.38, 392.04, 611.21, 977.19], dtype=torch.float64)
# Target (missing):  tensor([  4.26, 109.20, 222.38, 392.04, 611.21, 977.19], dtype=torch.float64)
# Outputs (missing):  tensor([  3.65,  96.37, 195.07, 352.93, 597.19, 946.44], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input:  tensor([  1.70,  13.03,  39.84,  39.75, 111.81,  92.96], dtype=torch.float64)
# Target:  tensor([  1.70,  13.03,  39.84,  39.75, 111.81,  92.96], dtype=torch.float64)
# Outputs:  tensor([ 2.42, 26.91, 44.26, 62.15, 88.72, 80.85], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([ 1.73, 17.80, 19.80, 34.72, 52.05,  0.00], dtype=torch.float64)
# Target (missing):  tensor([ 1.73, 17.80, 19.80, 34.72, 52.05, 63.88], dtype=torch.float64)
# Outputs (missing):  tensor([ 2.28, 17.60, 24.87, 34.25, 49.84, 65.74], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([  3.80,   0.00, 126.02, 204.85, 326.86, 489.21], dtype=torch.float64)
# Target (missing):  tensor([  3.80,  66.02, 126.02, 204.85, 326.86, 489.21], dtype=torch.float64)
# Outputs (missing):  tensor([  2.96,  57.32, 110.63, 190.70, 313.31, 466.96], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([  4.50,   0.00,   0.00, 512.90, 883.79,   0.00], dtype=torch.float64)
# Target (missing):  tensor([   4.50,  147.17,  292.79,  512.90,  883.79, 1476.67],
#        dtype=torch.float64)
# Outputs (missing):  tensor([   4.69,  125.35,  275.16,  508.24,  887.63, 1445.16],
#        dtype=torch.float64, grad_fn=<AddBackward0>)
# Input (missing):  tensor([  0.00,  89.84, 172.87, 288.35, 456.56,   0.00], dtype=torch.float64)
# Target (missing):  tensor([  4.03,  89.84, 172.87, 288.35, 456.56, 755.36], dtype=torch.float64)
# Outputs (missing):  tensor([  3.23,  69.44, 141.97, 260.02, 448.22, 727.22], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([   4.64,  163.76,  345.78,  644.15, 1080.71,    0.00],
#        dtype=torch.float64)
# Target (missing):  tensor([   4.64,  163.76,  345.78,  644.15, 1080.71, 1841.24],
#        dtype=torch.float64)
# Outputs (missing):  tensor([   4.78,  149.20,  321.62,  606.22, 1059.50, 1749.01],
#        dtype=torch.float64, grad_fn=<AddBackward0>)
# Input (missing):  tensor([ 1.32, 12.25, 18.77,  0.00, 43.67, 44.24], dtype=torch.float64)
# Target (missing):  tensor([ 1.32, 12.25, 18.77,  7.06, 43.67, 44.24], dtype=torch.float64)
# Outputs (missing):  tensor([ 2.29, 17.53, 24.33, 30.22, 39.65, 36.13], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([  0.00,  83.85, 133.73, 209.86, 277.83, 412.03], dtype=torch.float64)
# Target (missing):  tensor([  3.71,  83.85, 133.73, 209.86, 277.83, 412.03], dtype=torch.float64)
# Outputs (missing):  tensor([  2.99,  58.14, 110.89, 183.39, 292.18, 391.75], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([ 1.19,  0.00, 31.25,  5.83, 29.39,  0.00], dtype=torch.float64)
# Target (missing):  tensor([ 1.19, 11.38, 31.25,  5.83, 29.39, 49.52], dtype=torch.float64)
# Outputs (missing):  tensor([ 2.23, 14.85, 18.54, 22.78, 30.14, 37.48], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([  0.00,  42.41,  46.89,  79.31, 139.49, 106.00], dtype=torch.float64)
# Target (missing):  tensor([  2.83,  42.41,  46.89,  79.31, 139.49, 106.00], dtype=torch.float64)
# Outputs (missing):  tensor([  2.54,  33.31,  57.23,  81.10, 115.41,  93.61], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Epoch 110 of 110, Train Loss: 154.37444, Overall: 694.45910

# %%
# TRAIN THE NEURAL NETWORK
results = train(net)
# Out:
# 71.47], dtype=torch.float64)
# Target (missing):  tensor([  3.77,  63.96, 128.35, 214.41, 298.27, 471.47], dtype=torch.float64)
# Outputs (missing):  tensor([  2.53,  45.75,  89.29, 165.52, 288.40, 467.07], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([  0.00,  42.40,  65.05, 102.08,   0.00,   0.00], dtype=torch.float64)
# Target (missing):  tensor([  3.31,  42.40,  65.05, 102.08, 263.79, 290.97], dtype=torch.float64)
# Outputs (missing):  tensor([  2.35,  33.68,  61.79, 118.38, 205.34, 326.20], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([  2.52,  22.64,   0.00,  70.74,   0.00, 133.40], dtype=torch.float64)
# Target (missing):  tensor([  2.52,  22.64,  38.19,  70.74,  69.53, 133.40], dtype=torch.float64)
# Outputs (missing):  tensor([  2.22,  15.44,  28.14,  49.62,  85.00, 137.61], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input:  tensor([  3.97,  83.62, 156.91, 247.34, 403.51, 729.03], dtype=torch.float64)
# Target:  tensor([  3.97,  83.62, 156.91, 247.34, 403.51, 729.03], dtype=torch.float64)
# Outputs:  tensor([  3.05,  69.17, 137.70, 255.31, 445.87, 724.55], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input:  tensor([  1.40,  14.09,  11.94,  13.43, 116.75,  22.95], dtype=torch.float64)
# Target:  tensor([  1.40,  14.09,  11.94,  13.43, 116.75,  22.95], dtype=torch.float64)
# Outputs:  tensor([  2.21,  15.25,  27.63,  47.88,  80.45, 131.66], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([ 1.92, 10.12,  0.00,  0.00, 25.47,  0.00], dtype=torch.float64)
# Target (missing):  tensor([  1.92,  10.12,  28.23,  39.44,  25.47, 196.38], dtype=torch.float64)
# Outputs (missing):  tensor([ 2.07,  6.80, 10.50, 16.17, 25.76, 41.85], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([ 1.35,  5.81, 10.33, 29.91,  0.00, 29.25], dtype=torch.float64)
# Target (missing):  tensor([ 1.35,  5.81, 10.33, 29.91, 81.63, 29.25], dtype=torch.float64)
# Outputs (missing):  tensor([ 2.04,  8.01, 12.05, 20.81, 34.46, 53.59], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([  3.15,   0.00,  58.05, 103.29,   0.00, 276.33], dtype=torch.float64)
# Target (missing):  tensor([  3.15,  35.53,  58.05, 103.29, 195.76, 276.33], dtype=torch.float64)
# Outputs (missing):  tensor([  2.52,  28.43,  55.01,  99.16, 171.53, 279.56], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([  3.63,   0.00,  95.92, 155.66,   0.00, 436.44], dtype=torch.float64)
# Target (missing):  tensor([  3.63,  54.42,  95.92, 155.66, 253.31, 436.44], dtype=torch.float64)
# Outputs (missing):  tensor([  2.85,  42.88,  84.91, 154.37, 268.08, 437.85], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input:tensor([  3.13,  35.34,  64.42, 118.85, 144.54, 213.25], dtype=torch.float64)
# Target:  tensor([  3.13,  35.34,  64.42, 118.85, 144.54, 213.25], dtype=torch.float64)
# Outputs:  tensor([  2.30,  23.87,  44.30,  81.47, 140.95, 226.61], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([ 2.57,  0.00, 25.34,  0.00, 66.59, 64.54], dtype=torch.float64)
# Target (missing):  tensor([ 2.57, 26.55, 25.34, 56.99, 66.59, 64.54], dtype=torch.float64)
# Outputs (missing):  tensor([ 2.13,  9.20, 15.34, 25.72, 43.18, 69.38], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input:  tensor([   4.36,  136.10,  244.37,  427.54,  780.43, 1153.46],
#        dtype=torch.float64)
# Target:  tensor([   4.36,  136.10,  244.37,  427.54,  780.43, 1153.46],
#        dtype=torch.float64)
# Outputs:  tensor([   3.91,  110.55,  220.27,  411.70,  719.42, 1167.53],
#        dtype=torch.float64, grad_fn=<AddBackward0>)
# Input (missing):  tensor([ 1.18,  0.00, 28.08,  0.00,  0.00, 88.38], dtype=torch.float64)
# Target (missing):  tensor([ 1.18,  6.47, 28.08, 28.15, 61.78, 88.38], dtype=torch.float64)
# Outputs (missing):  tensor([ 2.24, 10.42, 18.76, 30.74, 51.94, 85.46], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([ 2.75, 26.65, 37.02,  0.00, 98.80,  0.00], dtype=torch.float64)
# Target (missing):  tensor([  2.75,  26.65,  37.02,  53.54,  98.80, 155.43], dtype=torch.float64)
# Outputs (missing):  tensor([  2.30,  17.75,  32.93,  56.57,  94.47, 156.37], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([ 1.95, 14.88,  0.00, 68.87,  0.00, 76.31], dtype=torch.float64)
# Target (missing):  tensor([ 1.95, 14.88, 12.66, 68.87, 45.05, 76.31], dtype=torch.float64)
# Outputs (missing):  tensor([ 2.12, 12.25, 20.45, 36.65, 62.02, 98.30], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([  0.00,  18.08,  39.31,  63.29,  77.85, 121.13], dtype=torch.float64)
# Target (missing):  tensor([  2.41,  18.08,  39.31,  63.29,  77.85, 121.13], dtype=torch.float64)
# Outputs (missing):  tensor([  2.20,  14.55,  25.70,  45.86,  78.47, 125.82], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input:  tensor([ 1.57,  8.33, 41.47, 19.78, 64.47, 86.29], dtype=torch.float64)
# Target:  tensor([ 1.57,  8.33, 41.47, 19.78, 64.47, 86.29], dtype=torch.float64)
# Outputs:  tensor([ 2.16, 11.17, 19.11, 33.06, 56.03, 89.87], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([  3.65,   0.00, 106.92, 167.88, 272.89, 379.40], dtype=torch.float64)
# Target (missing):  tensor([  3.65,  56.84, 106.92, 167.88, 272.89, 379.40], dtype=torch.float64)
# Outputs (missing):  tensor([  2.66,  38.26,  73.53, 135.81, 235.97, 381.60], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([  1.41,   0.00,  23.92,  17.05,  13.81, 117.33], dtype=torch.float64)
# Target (missing):  tensor([  1.41,  17.49,  23.92,  17.05,  13.81, 117.33], dtype=torch.float64)
# Outputs (missing):  tensor([  2.32,  13.02,  24.06,  40.59,  69.18, 113.57], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([ 0.00, 16.00, 11.15, 44.88, 38.00, 77.07], dtype=torch.float64)
# Target (missing):  tensor([ 1.53, 16.00, 11.15, 44.88, 38.00, 77.07], dtype=torch.float64)
# Outputs (missing):  tensor([ 2.14, 10.19, 17.05, 29.27, 49.38, 78.96], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([  2.76,  27.97,  44.30,   0.00, 148.07, 174.35], dtype=torch.float64)
# Target (missing):  tensor([  2.76,  27.97,  44.30,  56.86, 148.07, 174.35], dtype=torch.float64)
# Outputs (missing):  tensor([  2.41,  19.81,  37.18,  66.06, 113.81, 184.96], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([  3.92,  94.92,   0.00,   0.00, 390.02, 578.40], dtype=torch.float64)
# Target (missing):  tensor([  3.92,  94.92, 159.17, 273.37, 390.02, 578.40], dtype=torch.float64)
# Outputs (missing):  tensor([  3.56,  57.69, 117.53, 211.29, 368.01, 605.38], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input:  tensor([  2.73,  25.93,  42.54,  81.52, 135.00, 153.54], dtype=torch.float64)
# Target:  tensor([  2.73,  25.93,  42.54,  81.52, 135.00, 153.54], dtype=torch.float64)
# Outputs:  tensor([  2.28,  18.66,  33.70,  61.34, 105.67, 169.31], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([  3.98,  82.83,   0.00, 258.40,   0.00,   0.00], dtype=torch.float64)
# Target (missing):  tensor([  3.98,  82.83, 149.44, 258.40, 448.39, 629.40], dtype=torch.float64)
# Outputs (missing):  tensor([  3.54,  63.26, 120.40, 232.56, 408.55, 649.67], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([  3.93,  84.54, 165.17, 252.12,   0.00,   0.00], dtype=torch.float64)
# Target (missing):  tensor([  3.93,  84.54, 165.17, 252.12, 391.35, 602.61], dtype=torch.float64)
# Outputs (missing):  tensor([  3.45,  78.88, 147.63, 287.15, 500.31, 794.98], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input:  tensor([ 2.50, 16.20, 25.47, 57.58, 85.96, 62.91], dtype=torch.float64)
# Target:  tensor([ 2.50, 16.20, 25.47, 57.58, 85.96, 62.91], dtype=torch.float64)
# Outputs:  tensor([ 2.17, 11.75, 19.94, 35.15, 59.77, 95.19], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input:  tensor([ 2.10, 26.85, 27.84, 40.45, 51.72, 86.00], dtype=torch.float64)
# Target:  tensor([ 2.10, 26.85, 27.84, 40.45, 51.72, 86.00], dtype=torch.float64)
# Outputs:  tensor([ 2.17, 11.64, 19.81, 34.66, 58.82, 93.96], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([ 0.00, 17.53, 11.25, 20.87,  0.00,  0.00], dtype=torch.float64)
# Target (missing):tensor([  1.88,  17.53,  11.25,  20.87,  21.55, 118.61], dtype=torch.float64)
# Outputs (missing):  tensor([ 2.15, 10.06, 16.21, 28.44, 47.68, 75.23], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([ 1.59,  9.00,  8.12,  9.75, 31.90,  0.00], dtype=torch.float64)
# Target (missing):  tensor([ 1.59,  9.00,  8.12,  9.75, 31.90, 40.13], dtype=torch.float64)
# Outputs (missing):  tensor([ 2.14,  8.20, 13.23, 21.23, 34.49, 56.07], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([   0.00,  200.71,  422.09,  787.28, 1428.26, 2301.79],
#        dtype=torch.float64)
# Target (missing):  tensor([   4.81,  200.71,  422.09,  787.28, 1428.26, 2301.79],
#        dtype=torch.float64)
# Outputs (missing):  tensor([   7.07,  214.57,  430.63,  802.63, 1403.51, 2280.94],
#        dtype=torch.float64, grad_fn=<AddBackward0>)
# Input (missing):  tensor([  2.66,   0.00,  33.53,  40.28,  76.05, 153.43], dtype=torch.float64)
# Target (missing):  tensor([  2.66,  27.59,  33.53,  40.28,  76.05, 153.43], dtype=torch.float64)
# Outputs (missing):  tensor([  2.37,  16.84,  31.14,  54.60,  93.70, 152.26], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([ 0.00, 19.57, 32.48, 34.70, 65.14, 70.90], dtype=torch.float64)
# Target (missing):  tensor([ 2.49, 19.57, 32.48, 34.70, 65.14, 70.90], dtype=torch.float64)
# Outputs (missing):  tensor([ 2.14, 10.60, 17.65, 30.74, 52.03, 82.70], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([  1.28,  17.88,   0.00,  42.91,  42.23, 114.19], dtype=torch.float64)
# Target (missing):  tensor([  1.28,  17.88,  13.85,  42.91,  42.23, 114.19], dtype=torch.float64)
# Outputs (missing):  tensor([  2.27,  13.41,  24.09,  41.58,  70.93, 114.99], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input:  tensor([  1.90,  11.69,  26.86,  31.40,  40.91, 151.27], dtype=torch.float64)
# Target:  tensor([  1.90,  11.69,  26.86,  31.40,  40.91, 151.27], dtype=torch.float64)
# Outputs:  tensor([  2.37,  16.47,  30.80,  53.35,  91.51, 149.47], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([ 2.82, 27.95, 51.99,  0.00,  0.00,  0.00], dtype=torch.float64)
# Target (missing):  tensor([  2.82,  27.95,  51.99,  59.63, 110.91, 225.29], dtype=torch.float64)
# Outputs (missing):  tensor([ 2.05, 12.40, 20.03, 35.72, 58.90, 93.59], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input:  tensor([   4.42,  134.68,  281.33,  499.26,  812.26, 1265.65],
#        dtype=torch.float64)
# Target:  tensor([   4.42,  134.68,  281.33,  499.26,  812.26, 1265.65],
#        dtype=torch.float64)
# Outputs:  tensor([   4.19,  121.65,  241.14,  450.09,  786.21, 1274.21],
#        dtype=torch.float64, grad_fn=<AddBackward0>)
# Input (missing):  tensor([  2.99,  38.73,  45.13,   0.00, 109.47, 145.10], dtype=torch.float64)
# Target (missing):  tensor([  2.99,  38.73,  45.13,  72.79, 109.47, 145.10], dtype=torch.float64)
# Outputs (missing):  tensor([  2.31,  17.25,  31.70,  56.00,  96.16, 155.71], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([   0.00,  204.18,  437.26,  871.39, 1495.88,    0.00],
#        dtype=torch.float64)
# Target (missing):  tensor([   4.84,  204.18,  437.26,  871.39, 1495.88, 2463.99],
#        dtype=torch.float64)
# Outputs (missing):  tensor([   7.00,  244.82,  492.31,  899.23, 1543.46, 2539.81],
#        dtype=torch.float64, grad_fn=<AddBackward0>)
# Input:  tensor([  3.34,  49.63,  72.72, 122.89, 174.42, 246.04], dtype=torch.float64)
# Target:  tensor([  3.34,  49.63,  72.72, 122.89, 174.42, 246.04], dtype=torch.float64)
# Outputs:  tensor([  2.34,  27.52,  51.33,  94.50, 163.60, 263.00], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([ 2.70, 27.71,  0.00, 59.99,  0.00,  0.00], dtype=torch.float64)
# Target (missing):  tensor([ 2.70, 27.71, 36.52, 59.99, 94.08, 94.56], dtype=torch.float64)
# Outputs (missing):  tensor([  2.29,  18.10,  32.11,  59.44, 102.64, 162.69], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input: tensor([ 2.34, 18.80, 38.70, 34.06, 62.42, 54.70], dtype=torch.float64)
# Target:  tensor([ 2.34, 18.80, 38.70, 34.06, 62.42, 54.70], dtype=torch.float64)
# Outputs:  tensor([ 2.09, 10.19, 16.86, 29.23, 49.38, 78.40], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([  1.06,  11.76,  16.47,   0.00,  45.66, 107.61], dtype=torch.float64)
# Target (missing):  tensor([  1.06,  11.76,  16.47,  17.79,  45.66, 107.61], dtype=torch.float64)
# Outputs (missing):  tensor([  2.23,  12.79,  23.38,  39.52,  67.27, 110.02], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input:  tensor([ 2.56, 26.79, 61.56, 58.09, 66.29, 89.25], dtype=torch.float64)
# Target:  tensor([ 2.56, 26.79, 61.56, 58.09, 66.29, 89.25], dtype=torch.float64)
# Outputs:  tensor([  2.10,  13.46,  23.31,  41.62,  71.10, 113.30], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([ 1.36, 15.53, 18.30,  0.00, 52.65, 79.30], dtype=torch.float64)
# Target (missing):  tensor([ 1.36, 15.53, 18.30, 29.49, 52.65, 79.30], dtype=torch.float64)
# Outputs (missing):  tensor([ 2.14, 10.55, 18.29, 30.81, 52.05, 84.21], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([  3.46,  55.13,  92.33,   0.00, 322.06, 284.05], dtype=torch.float64)
# Target (missing):  tensor([  3.46,  55.13,  92.33, 132.86, 322.06, 284.05], dtype=torch.float64)
# Outputs (missing):  tensor([  2.33,  31.63,  60.44, 110.56, 191.60, 309.91], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([   4.65,  166.88,    0.00,    0.00,    0.00, 1905.82],
#        dtype=torch.float64)
# Target (missing):  tensor([   4.65,  166.88,  355.97,  639.18, 1094.52, 1905.82],
#        dtype=torch.float64)
# Outputs (missing):  tensor([   6.25,  167.21,  362.34,  636.45, 1111.20, 1856.26],
#        dtype=torch.float64, grad_fn=<AddBackward0>)
# Input (missing):  tensor([ 0.00, 27.10, 46.18,  0.00,  0.00,  0.00], dtype=torch.float64)
# Target (missing):  tensor([  2.95,  27.10,  46.18,  70.86, 128.90, 160.37], dtype=torch.float64)
# Outputs (missing):  tensor([ 1.97, 10.96, 17.41, 30.66, 50.25, 79.72], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([ 1.71,  0.00, 16.93,  0.00, 78.81, 97.81], dtype=torch.float64)
# Target (missing):  tensor([ 1.71,  7.71, 16.93, 27.75, 78.81, 97.81], dtype=torch.float64)
# Outputs (missing):  tensor([  2.14,  12.13,  21.73,  36.95,  62.77, 102.05], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([ 0.00,  7.33,  6.92,  0.00, 59.47, 86.82], dtype=torch.float64)
# Target (missing):  tensor([ 1.39,  7.33,  6.92, 15.28, 59.47, 86.82], dtype=torch.float64)
# Outputs (missing):  tensor([ 2.13, 11.01, 19.52, 32.73, 55.39, 90.17], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input:  tensor([  2.31,  17.50,  24.32,  31.57,  68.50, 156.71], dtype=torch.float64)
# Target:  tensor([  2.31,  17.50,  24.32,  31.57,  68.50, 156.71], dtype=torch.float64)
# Outputs:  tensor([  2.18,  17.29,  32.35,  56.66,  97.29, 158.39], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([ 1.16, 17.02,  0.00, 23.02, 40.89,  0.00], dtype=torch.float64)
# Target (missing):  tensor([ 1.16, 17.02, 10.06, 23.02, 40.89, 24.88], dtype=torch.float64)
# Outputs (missing):  tensor([ 2.07,  9.98, 16.87, 27.99, 46.13, 75.11], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([   4.74,  183.07,  384.90,    0.00, 1335.33,    0.00],
#        dtype=torch.float64)
# Target (missing):  tensor([   4.74,  183.07,  384.90,  763.30, 1335.33, 2083.49],
#        dtype=torch.float64)
# Outputs (missing):  tensor([   3.46,  182.39,  370.33,  666.11, 1133.33, 1881.80],
#        dtype=torch.float64, grad_fn=<AddBackward0>)
# Input (missing):  tensor([  2.91,   0.00,  45.15,   0.00, 103.31, 157.47], dtype=torch.float64)
# Target (missing):  tensor([  2.91,  26.86,  45.15,  61.32, 103.31, 157.47], dtype=torch.float64)
# Outputs (missing):  tensor([  2.18,  17.49,  32.94,  57.49,  98.71, 161.07], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([  4.26,   0.00, 222.38, 392.04, 611.21, 977.19], dtype=torch.float64)
# Target (missing):  tensor([  4.26, 109.20, 222.38, 392.04, 611.21, 977.19], dtype=torch.float64)
# Outputs (missing):  tensor([  2.55,  91.58, 182.03, 339.05, 591.72, 959.19], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input:  tensor([  1.70,  13.03,  39.84,  39.75, 111.81,  92.96], dtype=torch.float64)
# Target:  tensor([  1.70,  13.03,  39.84,  39.75, 111.81,  92.96], dtype=torch.float64)
# Outputs:  tensor([  2.03,  13.13,  22.72,  40.52,  69.15, 110.15], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([ 1.73, 17.80, 19.80, 34.72, 52.05,  0.00], dtype=torch.float64)
# Target (missing):  tensor([ 1.73, 17.80, 19.80, 34.72, 52.05, 63.88], dtype=torch.float64)
# Outputs (missing):  tensor([  2.08,  12.64,  22.26,  37.94,  63.17, 103.07], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([  3.80,   0.00, 126.02, 204.85, 326.86, 489.21], dtype=torch.float64)
# Target (missing):  tensor([  3.80,  66.02, 126.02, 204.85, 326.86, 489.21], dtype=torch.float64)
# Outputs (missing):  tensor([  2.27,  48.05,  93.54, 173.37, 301.52, 487.44], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([  4.50,   0.00,   0.00, 512.90, 883.79,   0.00], dtype=torch.float64)
# Target (missing):  tensor([   4.50,  147.17,  292.79,  512.90,  883.79, 1476.67],
#        dtype=torch.float64)
# Outputs (missing):  tensor([   3.48,  129.11,  259.26,  476.73,  821.07, 1344.14],
#        dtype=torch.float64, grad_fn=<AddBackward0>)
# Input (missing):  tensor([  0.00,  89.84, 172.87, 288.35, 456.56,   0.00], dtype=torch.float64)
# Target (missing):  tensor([  4.03,  89.84, 172.87, 288.35, 456.56, 755.36], dtype=torch.float64)
# Outputs (missing):  tensor([  2.72,  80.72, 160.43, 292.01, 499.17, 819.94], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([   4.64,  163.76,  345.78,  644.15, 1080.71,    0.00],
#        dtype=torch.float64)
# Target (missing):  tensor([   4.64,  163.76,  345.78,  644.15, 1080.71, 1841.24],
#        dtype=torch.float64)
# Outputs (missing):  tensor([   3.83,  180.68,  363.39,  665.57, 1140.82, 1874.09],
#        dtype=torch.float64, grad_fn=<AddBackward0>)
# Input (missing):  tensor([ 1.32, 12.25, 18.77,  0.00, 43.67, 44.24], dtype=torch.float64)
# Target (missing):  tensor([ 1.32, 12.25, 18.77,  7.06, 43.67, 44.24], dtype=torch.float64)
# Outputs (missing):  tensor([ 2.04,  7.49, 11.70, 19.08, 31.50, 49.98], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([  0.00,  83.85, 133.73, 209.86, 277.83, 412.03], dtype=torch.float64)
# Target (missing):  tensor([  3.71,  83.85, 133.73, 209.86, 277.83, 412.03], dtype=torch.float64)
# Outputs (missing):  tensor([  2.25,  43.63,  83.48, 156.25, 271.48, 436.27], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([ 1.19,  0.00, 31.25,  5.83, 29.39,  0.00], dtype=torch.float64)
# Target (missing):  tensor([ 1.19, 11.38, 31.25,  5.83, 29.39, 49.52], dtype=torch.float64)
# Outputs (missing):  tensor([ 2.06,  7.89, 12.63, 20.16, 32.57, 52.82], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([  0.00,  42.41,  46.89,  79.31, 139.49, 106.00], dtype=torch.float64)
# Target (missing):  tensor([  2.83,  42.41,  46.89,  79.31, 139.49, 106.00], dtype=torch.float64)
# Outputs (missing):  tensor([  2.11,  17.35,  31.06,  56.57,  97.19, 155.06], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Epoch 110 of 110, Train Loss: 931.99140, Overall: 1081.44448

# %%
# TRAIN THE NEURAL NETWORK
results = train(net)
# Out:
# 214.41, 298.27, 471.47], dtype=torch.float64)
# Target (missing):  tensor([  3.77,  63.96, 128.35, 214.41, 298.27, 471.47], dtype=torch.float64)
# Outputs (missing):  tensor([  3.50,  55.89, 103.03, 180.17, 302.01, 471.03], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([  0.00,  42.40,  65.05, 102.08,   0.00,   0.00], dtype=torch.float64)
# Target (missing):  tensor([  3.31,  42.40,  65.05, 102.08, 263.79, 290.97], dtype=torch.float64)
# Outputs (missing):  tensor([  2.72,  40.09,  68.45, 118.92, 200.76, 307.18], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([  2.52,  22.64,   0.00,  70.74,   0.00, 133.40], dtype=torch.float64)
# Target (missing):  tensor([  2.52,  22.64,  38.19,  70.74,  69.53, 133.40], dtype=torch.float64)
# Outputs (missing):  tensor([  2.38,  23.44,  35.48,  52.14,  80.10, 130.29], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input:  tensor([  3.97,  83.62, 156.91, 247.34, 403.51, 729.03], dtype=torch.float64)
# Target:  tensor([  3.97,  83.62, 156.91, 247.34, 403.51, 729.03], dtype=torch.float64)
# Outputs:  tensor([  4.08,  73.86, 142.60, 258.94, 441.17, 736.33], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input:  tensor([  1.40,  14.09,  11.94,  13.43, 116.75,  22.95], dtype=torch.float64)
# Target:  tensor([  1.40,  14.09,  11.94,  13.43, 116.75,  22.95], dtype=torch.float64)
# Outputs:  tensor([ 2.46, 27.29, 38.85, 56.01, 83.04, 76.76], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([ 1.92, 10.12,  0.00,  0.00, 25.47,  0.00], dtype=torch.float64)
# Target (missing):  tensor([  1.92,  10.12,  28.23,  39.44,  25.47, 196.38], dtype=torch.float64)
# Outputs (missing):  tensor([ 2.15, 16.14, 19.69, 21.79, 25.90, 39.45], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([ 1.35,  5.81, 10.33, 29.91,  0.00, 29.25], dtype=torch.float64)
# Target (missing):  tensor([ 1.35,  5.81, 10.33, 29.91, 81.63, 29.25], dtype=torch.float64)
# Outputs (missing):  tensor([ 2.19, 15.82, 20.10, 21.23, 25.36, 41.08], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([  3.15,   0.00,  58.05, 103.29,   0.00, 276.33], dtype=torch.float64)
# Target (missing):  tensor([  3.15,  35.53,  58.05, 103.29, 195.76, 276.33], dtype=torch.float64)
# Outputs (missing):  tensor([  2.66,  36.61,  61.25, 103.82, 171.26, 278.64], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([  3.63,   0.00,  95.92, 155.66,   0.00, 436.44], dtype=torch.float64)
# Target (missing):  tensor([  3.63,  54.42,  95.92, 155.66, 253.31, 436.44], dtype=torch.float64)
# Outputs (missing):  tensor([  2.98,  51.10,  89.81, 161.15, 272.56, 443.52], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input:  tensor([  3.13,  35.34,  64.42, 118.85, 144.54, 213.25], dtype=torch.float64)
# Target:  tensor([  3.13,  35.34,  64.42, 118.85, 144.54, 213.25], dtype=torch.float64)
# Outputs:  tensor([  2.86,  37.10,  60.98,  97.43, 155.14, 211.36], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([ 2.57,  0.00, 25.34,  0.00, 66.59, 64.54], dtype=torch.float64)
# Target (missing):  tensor([ 2.57, 26.55, 25.34, 56.99, 66.59, 64.54], dtype=torch.float64)
# Outputs (missing):  tensor([ 2.42, 24.16, 33.77, 45.44, 64.83, 60.06], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input:  tensor([   4.36,  136.10,  244.37,  427.54,  780.43, 1153.46],
#        dtype=torch.float64)
# Target:  tensor([   4.36,  136.10,  244.37,  427.54,  780.43, 1153.46],
#        dtype=torch.float64)
# Outputs:  tensor([   5.94,  133.70,  253.71,  463.01,  784.86, 1157.62],
#        dtype=torch.float64, grad_fn=<AddBackward0>)
# Input (missing):  tensor([ 1.18,  0.00, 28.08,  0.00,  0.00, 88.38], dtype=torch.float64)
# Target (missing):  tensor([ 1.18,  6.47, 28.08, 28.15, 61.78, 88.38], dtype=torch.float64)
# Outputs (missing):  tensor([ 2.28, 19.79, 27.81, 36.51, 52.10, 84.74], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([ 2.75, 26.65, 37.02,  0.00, 98.80,  0.00], dtype=torch.float64)
# Target (missing):  tensor([  2.75,  26.65,  37.02,  53.54,  98.80, 155.43], dtype=torch.float64)
# Outputs (missing):  tensor([  2.31,  28.10,  40.91,  67.15, 104.49, 164.28], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([ 1.95, 14.88,  0.00, 68.87,  0.00, 76.31], dtype=torch.float64)
# Target (missing):  tensor([ 1.95, 14.88, 12.66, 68.87, 45.05, 76.31], dtype=torch.float64)
# Outputs (missing):  tensor([ 2.27, 20.57, 29.31, 39.44, 57.44, 93.41], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing): tensor([  0.00,  18.08,  39.31,  63.29,  77.85, 121.13], dtype=torch.float64)
# Target (missing):  tensor([  2.41,  18.08,  39.31,  63.29,  77.85, 121.13], dtype=torch.float64)
# Outputs (missing):  tensor([  2.45,  25.51,  38.42,  54.76,  82.05, 112.83], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input:  tensor([ 1.57,  8.33, 41.47, 19.78, 64.47, 86.29], dtype=torch.float64)
# Target:  tensor([ 1.57,  8.33, 41.47, 19.78, 64.47, 86.29], dtype=torch.float64)
# Outputs:  tensor([ 2.38, 23.68, 34.01, 46.23, 66.98, 80.79], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([  3.65,   0.00, 106.92, 167.88, 272.89, 379.40], dtype=torch.float64)
# Target (missing):  tensor([  3.65,  56.84, 106.92, 167.88, 272.89, 379.40], dtype=torch.float64)
# Outputs (missing):  tensor([  3.16,  54.85,  95.46, 162.01, 266.72, 375.79], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([  1.41,   0.00,  23.92,  17.05,  13.81, 117.33], dtype=torch.float64)
# Target (missing):  tensor([  1.41,  17.49,  23.92,  17.05,  13.81, 117.33], dtype=torch.float64)
# Outputs (missing):  tensor([  2.30,  22.28,  32.80,  46.01,  68.85, 112.84], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([ 0.00, 16.00, 11.15, 44.88, 38.00, 77.07], dtype=torch.float64)
# Target (missing):  tensor([ 1.53, 16.00, 11.15, 44.88, 38.00, 77.07], dtype=torch.float64)
# Outputs (missing):  tensor([ 2.28, 19.28, 26.74, 32.98, 44.97, 66.92], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([  2.76,  27.97,  44.30,   0.00, 148.07, 174.35], dtype=torch.float64)
# Target (missing):  tensor([  2.76,  27.97,  44.30,  56.86, 148.07, 174.35], dtype=torch.float64)
# Outputs (missing):  tensor([  2.62,  37.02,  58.41,  91.53, 144.31, 171.30], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([  3.92,  94.92,   0.00,   0.00, 390.02, 578.40], dtype=torch.float64)
# Target (missing):  tensor([  3.92,  94.92, 159.17, 273.37, 390.02, 578.40], dtype=torch.float64)
# Outputs (missing):  tensor([  3.48,  72.25, 130.69, 228.85, 383.15, 566.18], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input:  tensor([  2.73,  25.93,  42.54,  81.52, 135.00, 153.54], dtype=torch.float64)
# Target:  tensor([  2.73,  25.93,  42.54,  81.52, 135.00, 153.54], dtype=torch.float64)
# Outputs:  tensor([  2.57,  35.90,  55.79,  86.15, 134.76, 150.77], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([  3.98,  82.83,   0.00, 258.40,   0.00,   0.00], dtype=torch.float64)
# Target (missing):  tensor([  3.98,  82.83, 149.44, 258.40, 448.39, 629.40], dtype=torch.float64)
# Outputs (missing):  tensor([  3.22,  76.74, 139.61, 253.44, 439.16, 657.99], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([  3.93,  84.54, 165.17, 252.12,   0.00,   0.00], dtype=torch.float64)
# Target (missing):  tensor([  3.93,  84.54, 165.17, 252.12, 391.35, 602.61], dtype=torch.float64)
# Outputs (missing):  tensor([  3.08,  81.90, 148.81, 277.19, 483.47, 758.15], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input:  tensor([ 2.50, 16.20, 25.47, 57.58, 85.96, 62.91], dtype=torch.float64)
# Target:  tensor([ 2.50, 16.20, 25.47, 57.58, 85.96, 62.91], dtype=torch.float64)
# Outputs:  tensor([ 2.39, 28.52, 40.29, 56.56, 83.15, 62.01], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input:  tensor([ 2.10, 26.85, 27.84, 40.45, 51.72, 86.00], dtype=torch.float64)
# Target:  tensor([ 2.10, 26.85, 27.84, 40.45, 51.72, 86.00], dtype=torch.float64)
# Outputs:  tensor([ 2.34, 22.62, 32.39, 43.00, 61.66, 80.10], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([ 0.00, 17.53, 11.25, 20.87,  0.00,  0.00], dtype=torch.float64)
# Target (missing):  tensor([  1.88,  17.53,  11.25,  20.87,  21.55, 118.61], dtype=torch.float64)
# Outputs (missing):  tensor([ 2.25, 19.92, 27.06, 33.60, 46.53, 57.85], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([ 1.59,  9.00,  8.12,  9.75, 31.90,  0.00], dtype=torch.float64)
# Target (missing):  tensor([ 1.59,  9.00,  8.12,  9.75, 31.90, 40.13], dtype=torch.float64)
# Outputs (missing):  tensor([ 2.15, 16.95, 20.93, 23.60, 28.78, 40.48], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([   0.00,  200.71,  422.09,  787.28, 1428.26, 2301.79],
#        dtype=torch.float64)
# Target (missing):  tensor([   4.81,  200.71,  422.09,  787.28, 1428.26, 2301.79],
#        dtype=torch.float64)
# Outputs (missing):  tensor([   7.81,  227.30,  447.26,  823.51, 1415.29, 2285.84],
#        dtype=torch.float64, grad_fn=<AddBackward0>)
# Input (missing):  tensor([  2.66,   0.00,  33.53,  40.28,  76.05, 153.43], dtype=torch.float64)
# Target (missing):  tensor([  2.66,  27.59,  33.53,  40.28,  76.05, 153.43], dtype=torch.float64)
# Outputs (missing):  tensor([  2.38,  25.22,  39.56,  57.42,  88.15, 147.74], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([ 0.00, 19.57, 32.48, 34.70, 65.14, 70.90], dtype=torch.float64)
# Target (missing):  tensor([ 2.49, 19.57, 32.48, 34.70, 65.14, 70.90], dtype=torch.float64)
# Outputs (missing):  tensor([ 2.28, 24.10, 33.91, 45.23, 64.86, 63.88], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([  1.28,  17.88,   0.00,  42.91,  42.23, 114.19], dtype=torch.float64)
# Target (missing):  tensor([  1.28,  17.88,  13.85,  42.91,  42.23, 114.19], dtype=torch.float64)
# Outputs (missing):  tensor([  2.21,  21.51,  32.00,  43.26,  63.78, 106.39], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input:  tensor([  1.90,  11.69,  26.86,  31.40,  40.91, 151.27], dtype=torch.float64)
# Target:  tensor([  1.90,  11.69,  26.86,  31.40,  40.91, 151.27], dtype=torch.float64)
# Outputs:  tensor([  2.18,  24.97,  38.91,  56.93,  88.21, 146.26], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([ 2.82, 27.95, 51.99,  0.00,  0.00,  0.00], dtype=torch.float64)
# Target (missing):  tensor([  2.82,  27.95,  51.99,  59.63, 110.91, 225.29], dtype=torch.float64)
# Outputs (missing):  tensor([ 2.00, 20.67, 28.13, 39.26, 57.54, 90.32], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input:  tensor([   4.42,  134.68,  281.33,  499.26,  812.26, 1265.65],
#        dtype=torch.float64)
# Target:  tensor([   4.42,  134.68,  281.33,  499.26,  812.26, 1265.65],
#        dtype=torch.float64)
# Outputs:  tensor([   2.69,  131.96,  259.20,  467.89,  804.28, 1261.34],
#        dtype=torch.float64, grad_fn=<AddBackward0>)
# Input (missing):  tensor([  2.99,  38.73,  45.13,   0.00, 109.47, 145.10], dtype=torch.float64)
# Target (missing):  tensor([  2.99,  38.73,  45.13,  72.79, 109.47, 145.10], dtype=torch.float64)
# Outputs (missing):  tensor([  2.18,  30.89,  48.48,  72.66, 113.18, 142.20], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([   0.00,  204.18,  437.26,  871.39, 1495.88,    0.00],
#        dtype=torch.float64)
# Target (missing):  tensor([   4.84,  204.18,  437.26,  871.39, 1495.88, 2463.99],
#        dtype=torch.float64)
# Outputs (missing):  tensor([    1.96,   217.53,   441.93,   852.09,  1504.23,  2515.97],
#        dtype=torch.float64, grad_fn=<AddBackward0>)
# Input:  tensor([  3.34,  49.63,  72.72, 122.89, 174.42, 246.04], dtype=torch.float64)
# Target:  tensor([  3.34,  49.63,  72.72, 122.89, 174.42, 246.04], dtype=torch.float64)
# Outputs:  tensor([  2.33,  40.79,  69.30, 111.42, 180.47, 243.68], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([ 2.70, 27.71,  0.00, 59.99,  0.00,  0.00], dtype=torch.float64)
# Target (missing):  tensor([ 2.70, 27.71, 36.52, 59.99, 94.08, 94.56], dtype=torch.float64)
# Outputs (missing):  tensor([  2.22,  26.58,  41.07,  59.73,  92.90, 118.99], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input:  tensor([ 2.34, 18.80, 38.70, 34.06, 62.42, 54.70], dtype=torch.float64)
# Target:  tensor([ 2.34, 18.80, 38.70, 34.06, 62.42, 54.70], dtype=torch.float64)
# Outputs:  tensor([ 2.25, 24.18, 33.93, 45.09, 64.35, 51.87], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([  1.06,  11.76,  16.47,   0.00,  45.66, 107.61], dtype=torch.float64)
# Target (missing):  tensor([  1.06,  11.76,  16.47,  17.79,  45.66, 107.61], dtype=torch.float64)
# Outputs (missing):  tensor([  2.27,  20.55,  30.93,  41.31,  60.33, 100.71], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input:  tensor([ 2.56, 26.79, 61.56, 58.09, 66.29, 89.25], dtype=torch.float64)
# Target:  tensor([ 2.56, 26.79, 61.56, 58.09, 66.29, 89.25], dtype=torch.float64)
# Outputs:  tensor([ 2.35, 24.54, 36.57, 50.54, 74.50, 86.87], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([ 1.36, 15.53, 18.30,  0.00, 52.65, 79.30], dtype=torch.float64)
# Target (missing):  tensor([ 1.36, 15.53, 18.30, 29.49, 52.65, 79.30], dtype=torch.float64)
# Outputs (missing):  tensor([ 2.31, 21.04, 30.31, 39.27, 55.47, 71.09], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([  3.46,  55.13,  92.33,   0.00, 322.06, 284.05], dtype=torch.float64)
# Target (missing): tensor([  3.46,  55.13,  92.33, 132.86, 322.06, 284.05], dtype=torch.float64)
# Outputs (missing):  tensor([  3.22,  62.65, 106.33, 178.66, 291.36, 288.50], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([   4.65,  166.88,    0.00,    0.00,    0.00, 1905.82],
#        dtype=torch.float64)
# Target (missing):  tensor([   4.65,  166.88,  355.97,  639.18, 1094.52, 1905.82],
#        dtype=torch.float64)
# Outputs (missing):  tensor([   5.78,  169.21,  344.15,  664.55, 1166.34, 1904.88],
#        dtype=torch.float64, grad_fn=<AddBackward0>)
# Input (missing):  tensor([ 0.00, 27.10, 46.18,  0.00,  0.00,  0.00], dtype=torch.float64)
# Target (missing):  tensor([  2.95,  27.10,  46.18,  70.86, 128.90, 160.37], dtype=torch.float64)
# Outputs (missing):  tensor([ 2.20, 20.19, 28.16, 39.59, 58.07, 90.91], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([ 1.71,  0.00, 16.93,  0.00, 78.81, 97.81], dtype=torch.float64)
# Target (missing):  tensor([ 1.71,  7.71, 16.93, 27.75, 78.81, 97.81], dtype=torch.float64)
# Outputs (missing):  tensor([ 2.44, 24.15, 36.36, 50.25, 74.08, 88.70], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([ 0.00,  7.33,  6.92,  0.00, 59.47, 86.82], dtype=torch.float64)
# Target (missing):  tensor([ 1.39,  7.33,  6.92, 15.28, 59.47, 86.82], dtype=torch.float64)
# Outputs (missing):  tensor([ 2.37, 20.99, 30.75, 39.98, 56.76, 74.84], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input:  tensor([  2.31,  17.50,  24.32,  31.57,  68.50, 156.71], dtype=torch.float64)
# Target:  tensor([  2.31,  17.50,  24.32,  31.57,  68.50, 156.71], dtype=torch.float64)
# Outputs:  tensor([  2.53,  24.04,  39.72,  57.77,  88.92, 149.47], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([ 1.16, 17.02,  0.00, 23.02, 40.89,  0.00], dtype=torch.float64)
# Target (missing):  tensor([ 1.16, 17.02, 10.06, 23.02, 40.89, 24.88], dtype=torch.float64)
# Outputs (missing):  tensor([ 2.20, 17.30, 22.35, 25.99, 32.88, 42.91], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([   4.74,  183.07,  384.90,    0.00, 1335.33,    0.00],
#        dtype=torch.float64)
# Target (missing):  tensor([   4.74,  183.07,  384.90,  763.30, 1335.33, 2083.49],
#        dtype=torch.float64)
# Outputs (missing):  tensor([   5.78,  195.30,  376.07,  769.78, 1331.46, 2131.43],
#        dtype=torch.float64, grad_fn=<AddBackward0>)
# Input (missing):  tensor([  2.91,   0.00,  45.15,   0.00, 103.31, 157.47], dtype=torch.float64)
# Target (missing):  tensor([  2.91,  26.86,  45.15,  61.32, 103.31, 157.47], dtype=torch.float64)
# Outputs (missing):  tensor([  2.59,  26.66,  44.31,  65.09, 100.48, 148.33], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([  4.26,   0.00, 222.38, 392.04, 611.21, 977.19], dtype=torch.float64)
# Target (missing):  tensor([  4.26, 109.20, 222.38, 392.04, 611.21, 977.19], dtype=torch.float64)
# Outputs (missing):  tensor([  4.83,  89.06, 191.41, 339.59, 579.38, 955.24], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input:  tensor([  1.70,  13.03,  39.84,  39.75, 111.81,  92.96], dtype=torch.float64)
# Target:  tensor([  1.70,  13.03,  39.84,  39.75, 111.81,  92.96], dtype=torch.float64)
# Outputs:  tensor([  2.52,  30.14,  46.30,  67.13, 102.02,  87.55], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([ 1.73, 17.80, 19.80, 34.72, 52.05,  0.00], dtype=torch.float64)
# Target (missing):  tensor([ 1.73, 17.80, 19.80, 34.72, 52.05, 63.88], dtype=torch.float64)
# Outputs (missing):  tensor([ 2.20, 18.51, 25.26, 31.55, 42.59, 58.26], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([  3.80,   0.00, 126.02, 204.85, 326.86, 489.21], dtype=torch.float64)
# Target (missing):  tensor([  3.80,  66.02, 126.02, 204.85, 326.86, 489.21], dtype=torch.float64)
# Outputs (missing):  tensor([  3.37,  55.39, 110.59, 186.51, 310.53, 472.11], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([  4.50,   0.00,   0.00, 512.90, 883.79,   0.00], dtype=torch.float64)
# Target (missing):  tensor([   4.50,  147.17,  292.79,  512.90,  883.79, 1476.67],
#        dtype=torch.float64)
# Outputs (missing):  tensor([   5.75,  122.95,  278.90,  505.38,  879.44, 1418.58],
#        dtype=torch.float64, grad_fn=<AddBackward0>)
# Input (missing):  tensor([  0.00,  89.84, 172.87, 288.35, 456.56,   0.00], dtype=torch.float64)
# Target (missing):  tensor([  4.03,  89.84, 172.87, 288.35, 456.56, 755.36], dtype=torch.float64)
# Outputs (missing):  tensor([  3.36,  66.49, 139.38, 252.18, 431.30, 723.43], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([   4.64,  163.76,  345.78,  644.15, 1080.71,    0.00],
#        dtype=torch.float64)
# Target (missing):  tensor([   4.64,  163.76,  345.78,  644.15, 1080.71, 1841.24],
#        dtype=torch.float64)
# Outputs (missing):  tensor([   4.90,  142.66,  317.59,  594.72, 1033.64, 1737.72],
#        dtype=torch.float64, grad_fn=<AddBackward0>)
# Input (missing):  tensor([ 1.32, 12.25, 18.77,  0.00, 43.67, 44.24], dtype=torch.float64)
# Target (missing):  tensor([ 1.32, 12.25, 18.77,  7.06, 43.67, 44.24], dtype=torch.float64)
# Outputs (missing):  tensor([ 2.22, 20.15, 27.61, 33.17, 44.34, 37.16], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([  0.00,  83.85, 133.73, 209.86, 277.83, 412.03], dtype=torch.float64)
# Target (missing):  tensor([  3.71,  83.85, 133.73, 209.86, 277.83, 412.03], dtype=torch.float64)
# Outputs (missing):  tensor([  2.86,  53.88, 103.49, 171.17, 281.79, 403.75], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([ 1.19,  0.00, 31.25,  5.83, 29.39,  0.00], dtype=torch.float64)
# Target (missing):  tensor([ 1.19, 11.38, 31.25,  5.83, 29.39, 49.52], dtype=torch.float64)
# Outputs (missing):  tensor([ 2.09, 16.09, 20.38, 22.31, 26.55, 40.51], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([  0.00,  42.41,  46.89,  79.31, 139.49, 106.00], dtype=torch.float64)
# Target (missing):  tensor([  2.83,  42.41,  46.89,  79.31, 139.49, 106.00], dtype=torch.float64)
# Outputs (missing):  tensor([  2.39,  36.36,  56.89,  84.95, 131.36, 103.92], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Epoch 110 of 110, Train Loss: 39.84270, Overall: 574.55123

# %%
# TRAIN THE NEURAL NETWORK
results = train(net)
# Out:
# .41, 298.27, 471.47], dtype=torch.float64)
# Target (missing):  tensor([  3.77,  63.96, 128.35, 214.41, 298.27, 471.47], dtype=torch.float64)
# Outputs (missing):  tensor([  3.47,  54.90, 101.33, 176.49, 294.08, 469.84], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([  0.00,  42.40,  65.05, 102.08,   0.00,   0.00], dtype=torch.float64)
# Target (missing):  tensor([  3.31,  42.40,  65.05, 102.08, 263.79, 290.97], dtype=torch.float64)
# Outputs (missing):  tensor([  2.86,  41.06,  71.40, 119.08, 200.75, 307.36], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([  2.52,  22.64,   0.00,  70.74,   0.00, 133.40], dtype=torch.float64)
# Target (missing):  tensor([  2.52,  22.64,  38.19,  70.74,  69.53, 133.40], dtype=torch.float64)
# Outputs (missing):  tensor([  2.52,  23.72,  37.37,  52.19,  77.87, 130.28], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input:  tensor([  3.97,  83.62, 156.91, 247.34, 403.51, 729.03], dtype=torch.float64)
# Target:  tensor([  3.97,  83.62, 156.91, 247.34, 403.51, 729.03], dtype=torch.float64)
# Outputs:  tensor([  4.08,  71.67, 139.97, 251.91, 424.20, 734.78], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input: tensor([  1.40,  14.09,  11.94,  13.43, 116.75,  22.95], dtype=torch.float64)
# Target:  tensor([  1.40,  14.09,  11.94,  13.43, 116.75,  22.95], dtype=torch.float64)
# Outputs:  tensor([ 2.53, 26.85, 38.35, 52.70, 78.99, 68.01], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([ 1.92, 10.12,  0.00,  0.00, 25.47,  0.00], dtype=torch.float64)
# Target (missing):  tensor([  1.92,  10.12,  28.23,  39.44,  25.47, 196.38], dtype=torch.float64)
# Outputs (missing):  tensor([ 2.33, 16.95, 22.66, 24.79, 28.81, 47.48], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([ 1.35,  5.81, 10.33, 29.91,  0.00, 29.25], dtype=torch.float64)
# Target (missing):  tensor([ 1.35,  5.81, 10.33, 29.91, 81.63, 29.25], dtype=torch.float64)
# Outputs (missing):  tensor([ 2.31, 15.84, 21.41, 21.23, 21.91, 41.51], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([  3.15,   0.00,  58.05, 103.29,   0.00, 276.33], dtype=torch.float64)
# Target (missing):  tensor([  3.15,  35.53,  58.05, 103.29, 195.76, 276.33], dtype=torch.float64)
# Outputs (missing):  tensor([  2.86,  37.06,  63.68, 102.72, 168.81, 273.68], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([  3.63,   0.00,  95.92, 155.66,   0.00, 436.44], dtype=torch.float64)
# Target (missing):  tensor([  3.63,  54.42,  95.92, 155.66, 253.31, 436.44], dtype=torch.float64)
# Outputs (missing):  tensor([  3.24,  51.91,  93.16, 159.51, 271.17, 435.49], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input:  tensor([  3.13,  35.34,  64.42, 118.85, 144.54, 213.25], dtype=torch.float64)
# Target:  tensor([  3.13,  35.34,  64.42, 118.85, 144.54, 213.25], dtype=torch.float64)
# Outputs:  tensor([  2.88,  36.26,  59.97,  94.39, 149.70, 212.71], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([ 2.57,  0.00, 25.34,  0.00, 66.59, 64.54], dtype=torch.float64)
# Target (missing):  tensor([ 2.57, 26.55, 25.34, 56.99, 66.59, 64.54], dtype=torch.float64)
# Outputs (missing):  tensor([ 2.49, 25.15, 35.46, 46.85, 68.13, 58.15], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input:  tensor([   4.36,  136.10,  244.37,  427.54,  780.43, 1153.46],
#        dtype=torch.float64)
# Target:  tensor([   4.36,  136.10,  244.37,  427.54,  780.43, 1153.46],
#        dtype=torch.float64)
# Outputs:  tensor([   5.64,  130.95,  246.08,  452.49,  774.06, 1160.58],
#        dtype=torch.float64, grad_fn=<AddBackward0>)
# Input (missing):  tensor([ 1.18,  0.00, 28.08,  0.00,  0.00, 88.38], dtype=torch.float64)
# Target (missing):  tensor([ 1.18,  6.47, 28.08, 28.15, 61.78, 88.38], dtype=torch.float64)
# Outputs (missing):  tensor([ 2.41, 19.83, 29.14, 35.95, 48.31, 82.56], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([ 2.75, 26.65, 37.02,  0.00, 98.80,  0.00], dtype=torch.float64)
# Target (missing):  tensor([  2.75,  26.65,  37.02,  53.54,  98.80, 155.43], dtype=torch.float64)
# Outputs (missing):  tensor([  2.69,  30.23,  47.60,  73.64, 115.19, 179.49], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([ 1.95, 14.88,  0.00, 68.87,  0.00, 76.31], dtype=torch.float64)
# Target (missing):  tensor([ 1.95, 14.88, 12.66, 68.87, 45.05, 76.31], dtype=torch.float64)
# Outputs (missing):  tensor([ 2.41, 20.78, 31.15, 39.66, 55.00, 94.19], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([  0.00,  18.08,  39.31,  63.29,  77.85, 121.13], dtype=torch.float64)
# Target (missing):  tensor([  2.41,  18.08,  39.31,  63.29,  77.85, 121.13], dtype=torch.float64)
# Outputs (missing):  tensor([  2.52,  24.81,  38.24,  52.67,  76.37, 114.67], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input:  tensor([ 1.57,  8.33, 41.47, 19.78, 64.47, 86.29], dtype=torch.float64)
# Target:  tensor([ 1.57,  8.33, 41.47, 19.78, 64.47, 86.29], dtype=torch.float64)
# Outputs:  tensor([ 2.45, 23.87, 34.89, 46.00, 65.57, 80.02], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([  3.65,   0.00, 106.92, 167.88, 272.89, 379.40], dtype=torch.float64)
# Target (missing):  tensor([  3.65,  56.84, 106.92, 167.88, 272.89, 379.40], dtype=torch.float64)
# Outputs (missing):  tensor([  3.14,  55.46,  95.44, 161.69, 268.15, 374.01], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([  1.41,   0.00,  23.92,  17.05,  13.81, 117.33], dtype=torch.float64)
# Target (missing):  tensor([  1.41,  17.49,  23.92,  17.05,  13.81, 117.33], dtype=torch.float64)
# Outputs (missing):  tensor([  2.43,  22.19,  33.90,  44.96,  64.14, 109.62], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([ 0.00, 16.00, 11.15, 44.88, 38.00, 77.07], dtype=torch.float64)
# Target (missing):  tensor([ 1.53, 16.00, 11.15, 44.88, 38.00, 77.07], dtype=torch.float64)
# Outputs (missing):  tensor([ 2.37, 18.70, 27.18, 31.68, 39.36, 69.81], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([  2.76,  27.97,  44.30,   0.00, 148.07, 174.35], dtype=torch.float64)
# Target (missing):  tensor([  2.76,  27.97,  44.30,  56.86, 148.07, 174.35], dtype=torch.float64)
# Outputs (missing):  tensor([  2.65,  38.35,  59.88,  93.16, 149.76, 168.41], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([  3.92,  94.92,   0.00,   0.00, 390.02, 578.40], dtype=torch.float64)
# Target (missing):  tensor([  3.92,  94.92, 159.17, 273.37, 390.02, 578.40], dtype=torch.float64)
# Outputs (missing):  tensor([  3.42,  74.97, 133.09, 233.79, 394.78, 565.26], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input:  tensor([  2.73,  25.93,  42.54,  81.52, 135.00, 153.54], dtype=torch.float64)
# Target:  tensor([  2.73,  25.93,  42.54,  81.52, 135.00, 153.54], dtype=torch.float64)
# Outputs:  tensor([  2.60,  36.40,  56.25,  85.90, 136.85, 150.38], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([  3.98,  82.83,   0.00, 258.40,   0.00,   0.00], dtype=torch.float64)
# Target (missing):  tensor([  3.98,  82.83, 149.44, 258.40, 448.39, 629.40], dtype=torch.float64)
# Outputs (missing):  tensor([  3.35,  81.90, 147.47, 258.49, 446.88, 641.84], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([  3.93,  84.54, 165.17, 252.12,   0.00,   0.00], dtype=torch.float64)
# Target (missing):  tensor([  3.93,  84.54, 165.17, 252.12, 391.35, 602.61], dtype=torch.float64)
# Outputs (missing):  tensor([  3.22,  83.73, 152.30, 273.57, 479.34, 732.66], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input:  tensor([ 2.50, 16.20, 25.47, 57.58, 85.96, 62.91], dtype=torch.float64)
# Target:  tensor([ 2.50, 16.20, 25.47, 57.58, 85.96, 62.91], dtype=torch.float64)
# Outputs:  tensor([ 2.44, 27.75, 39.62, 54.17, 81.23, 69.32], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input:  tensor([ 2.10, 26.85, 27.84, 40.45, 51.72, 86.00], dtype=torch.float64)
# Target:  tensor([ 2.10, 26.85, 27.84, 40.45, 51.72, 86.00], dtype=torch.float64)
# Outputs:  tensor([ 2.42, 22.29, 32.83, 41.90, 57.69, 81.39], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([ 0.00, 17.53, 11.25, 20.87,  0.00,  0.00], dtype=torch.float64)
# Target (missing):  tensor([  1.88,  17.53,  11.25,  20.87,  21.55, 118.61], dtype=torch.float64)
# Outputs (missing):  tensor([ 2.39, 20.99, 30.26, 36.48, 48.79, 65.95], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([ 1.59,  9.00,  8.12,  9.75, 31.90,  0.00], dtype=torch.float64)
# Target (missing):  tensor([ 1.59,  9.00,  8.12,  9.75, 31.90, 40.13], dtype=torch.float64)
# Outputs (missing):  tensor([ 2.30, 17.34, 23.11, 25.36, 29.76, 47.49], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([   0.00,  200.71,  422.09,  787.28, 1428.26, 2301.79],
#        dtype=torch.float64)
# Target (missing):  tensor([   4.81,  200.71,  422.09,  787.28, 1428.26, 2301.79],
#        dtype=torch.float64)
# Outputs (missing):  tensor([   7.14,  222.29,  435.43,  810.53, 1392.08, 2295.50],
#        dtype=torch.float64, grad_fn=<AddBackward0>)
# Input (missing):  tensor([  2.66,   0.00,  33.53,  40.28,  76.05, 153.43], dtype=torch.float64)
# Target (missing):  tensor([  2.66,  27.59,  33.53,  40.28,  76.05, 153.43], dtype=torch.float64)
# Outputs (missing):  tensor([  2.47,  24.75,  39.89,  56.00,  81.46, 145.82], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([ 0.00, 19.57, 32.48, 34.70, 65.14, 70.90], dtype=torch.float64)
# Target (missing):  tensor([ 2.49, 19.57, 32.48, 34.70, 65.14, 70.90], dtype=torch.float64)
# Outputs (missing):  tensor([ 2.36, 24.03, 34.34, 44.32, 63.14, 64.36], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([  1.28,  17.88,   0.00,  42.91,  42.23, 114.19], dtype=torch.float64)
# Target (missing):  tensor([  1.28,  17.88,  13.85,  42.91,  42.23, 114.19], dtype=torch.float64)
# Outputs (missing):  tensor([  2.32,  21.09,  32.45,  41.83,  57.54, 103.79], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input:  tensor([  1.90,  11.69,  26.86,  31.40,  40.91, 151.27], dtype=torch.float64)
# Target:  tensor([  1.90,  11.69,  26.86,  31.40,  40.91, 151.27], dtype=torch.float64)
# Outputs:  tensor([  2.31,  24.52,  39.30,  54.84,  81.23, 141.00], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):tensor([ 2.82, 27.95, 51.99,  0.00,  0.00,  0.00], dtype=torch.float64)
# Target (missing):  tensor([  2.82,  27.95,  51.99,  59.63, 110.91, 225.29], dtype=torch.float64)
# Outputs (missing):  tensor([  2.24,  23.50,  35.19,  48.42,  72.20, 112.06], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input:  tensor([   4.42,  134.68,  281.33,  499.26,  812.26, 1265.65],
#        dtype=torch.float64)
# Target:  tensor([   4.42,  134.68,  281.33,  499.26,  812.26, 1265.65],
#        dtype=torch.float64)
# Outputs:  tensor([   2.60,  133.59,  257.93,  469.57,  808.23, 1262.40],
#        dtype=torch.float64, grad_fn=<AddBackward0>)
# Input (missing):  tensor([  2.99,  38.73,  45.13,   0.00, 109.47, 145.10], dtype=torch.float64)
# Target (missing):  tensor([  2.99,  38.73,  45.13,  72.79, 109.47, 145.10], dtype=torch.float64)
# Outputs (missing):  tensor([  2.27,  31.97,  50.09,  74.22, 116.28, 140.33], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([   0.00,  204.18,  437.26,  871.39, 1495.88,    0.00],
#        dtype=torch.float64)
# Target (missing):  tensor([   4.84,  204.18,  437.26,  871.39, 1495.88, 2463.99],
#        dtype=torch.float64)
# Outputs (missing):  tensor([    2.42,   226.17,   447.90,   861.65,  1523.50,  2500.05],
#        dtype=torch.float64, grad_fn=<AddBackward0>)
# Input:  tensor([  3.34,  49.63,  72.72, 122.89, 174.42, 246.04], dtype=torch.float64)
# Target:  tensor([  3.34,  49.63,  72.72, 122.89, 174.42, 246.04], dtype=torch.float64)
# Outputs:  tensor([  2.44,  41.28,  69.84, 111.52, 181.28, 243.86], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([ 2.70, 27.71,  0.00, 59.99,  0.00,  0.00], dtype=torch.float64)
# Target (missing):  tensor([ 2.70, 27.71, 36.52, 59.99, 94.08, 94.56], dtype=torch.float64)
# Outputs (missing):  tensor([  2.42,  28.01,  44.66,  61.78,  93.58, 119.48], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input:  tensor([ 2.34, 18.80, 38.70, 34.06, 62.42, 54.70], dtype=torch.float64)
# Target:  tensor([ 2.34, 18.80, 38.70, 34.06, 62.42, 54.70], dtype=torch.float64)
# Outputs:  tensor([ 2.37, 24.36, 34.63, 44.73, 64.58, 53.01], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([  1.06,  11.76,  16.47,   0.00,  45.66, 107.61], dtype=torch.float64)
# Target (missing):  tensor([  1.06,  11.76,  16.47,  17.79,  45.66, 107.61], dtype=torch.float64)
# Outputs (missing):  tensor([ 2.40, 20.05, 31.34, 39.74, 53.53, 97.86], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input:  tensor([ 2.56, 26.79, 61.56, 58.09, 66.29, 89.25], dtype=torch.float64)
# Target:  tensor([ 2.56, 26.79, 61.56, 58.09, 66.29, 89.25], dtype=torch.float64)
# Outputs:  tensor([ 2.48, 24.47, 37.08, 49.69, 72.15, 86.36], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([ 1.36, 15.53, 18.30,  0.00, 52.65, 79.30], dtype=torch.float64)
# Target (missing):  tensor([ 1.36, 15.53, 18.30, 29.49, 52.65, 79.30], dtype=torch.float64)
# Outputs (missing):  tensor([ 2.44, 21.56, 31.97, 40.33, 55.48, 70.84], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([  3.46,  55.13,  92.33,   0.00, 322.06, 284.05], dtype=torch.float64)
# Target (missing):  tensor([  3.46,  55.13,  92.33, 132.86, 322.06, 284.05], dtype=torch.float64)
# Outputs (missing):  tensor([  3.43,  65.85, 108.56, 183.38, 312.88, 283.68], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([   4.65,  166.88,    0.00,    0.00,    0.00, 1905.82],
#        dtype=torch.float64)
# Target (missing):  tensor([   4.65,  166.88,  355.97,  639.18, 1094.52, 1905.82],
#        dtype=torch.float64)
# Outputs (missing):  tensor([   7.30,  172.60,  357.91,  662.50, 1176.51, 1872.34],
#        dtype=torch.float64, grad_fn=<AddBackward0>)
# Input (missing):  tensor([ 0.00, 27.10, 46.18,  0.00,  0.00,  0.00], dtype=torch.float64)
# Target (missing):  tensor([  2.95,  27.10,  46.18,  70.86, 128.90, 160.37], dtype=torch.float64)
# Outputs (missing):  tensor([  2.50,  23.14,  36.09,  50.38,  75.89, 117.58], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([ 1.71,  0.00, 16.93,  0.00, 78.81, 97.81], dtype=torch.float64)
# Target (missing):  tensor([ 1.71,  7.71, 16.93, 27.75, 78.81, 97.81], dtype=torch.float64)
# Outputs (missing):  tensor([ 2.54, 25.41, 38.77, 52.95, 78.27, 87.12], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([ 0.00,  7.33,  6.92,  0.00, 59.47, 86.82], dtype=torch.float64)
# Target (missing):  tensor([ 1.39,  7.33,  6.92, 15.28, 59.47, 86.82], dtype=torch.float64)
# Outputs (missing):  tensor([ 2.45, 21.55, 32.53, 41.39, 57.18, 75.24], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input:  tensor([  2.31,  17.50,  24.32,  31.57,  68.50, 156.71], dtype=torch.float64)
# Target:  tensor([  2.31,  17.50,  24.32,  31.57,  68.50, 156.71], dtype=torch.float64)
# Outputs:  tensor([  2.55,  23.29,  39.87,  55.82,  80.92, 146.75], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([ 1.16, 17.02,  0.00, 23.02, 40.89,  0.00], dtype=torch.float64)
# Target (missing):  tensor([ 1.16, 17.02, 10.06, 23.02, 40.89, 24.88], dtype=torch.float64)
# Outputs (missing):  tensor([ 2.32, 17.55, 24.36, 27.49, 33.50, 48.91], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([   4.74,  183.07,  384.90,    0.00, 1335.33,    0.00],
#        dtype=torch.float64)
# Target (missing):  tensor([   4.74,  183.07,  384.90,  763.30, 1335.33, 2083.49],
#        dtype=torch.float64)
# Outputs (missing):  tensor([   6.70,  197.62,  402.65,  767.21, 1342.35, 2084.26],
#        dtype=torch.float64, grad_fn=<AddBackward0>)
# Input (missing): tensor([  2.91,   0.00,  45.15,   0.00, 103.31, 157.47], dtype=torch.float64)
# Target (missing):  tensor([  2.91,  26.86,  45.15,  61.32, 103.31, 157.47], dtype=torch.float64)
# Outputs (missing):  tensor([  2.50,  27.97,  46.78,  68.46, 104.31, 146.25], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([  4.26,   0.00, 222.38, 392.04, 611.21, 977.19], dtype=torch.float64)
# Target (missing):  tensor([  4.26, 109.20, 222.38, 392.04, 611.21, 977.19], dtype=torch.float64)
# Outputs (missing):  tensor([  3.41,  91.32, 193.19, 348.07, 587.60, 951.10], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input:  tensor([  1.70,  13.03,  39.84,  39.75, 111.81,  92.96], dtype=torch.float64)
# Target:  tensor([  1.70,  13.03,  39.84,  39.75, 111.81,  92.96], dtype=torch.float64)
# Outputs:  tensor([  2.41,  30.33,  46.64,  67.25, 104.82,  90.91], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([ 1.73, 17.80, 19.80, 34.72, 52.05,  0.00], dtype=torch.float64)
# Target (missing):  tensor([ 1.73, 17.80, 19.80, 34.72, 52.05, 63.88], dtype=torch.float64)
# Outputs (missing):  tensor([ 2.23, 18.55, 26.82, 32.64, 42.53, 64.40], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([  3.80,   0.00, 126.02, 204.85, 326.86, 489.21], dtype=torch.float64)
# Target (missing):  tensor([  3.80,  66.02, 126.02, 204.85, 326.86, 489.21], dtype=torch.float64)
# Outputs (missing):  tensor([  2.48,  56.65, 111.41, 191.47, 317.24, 473.79], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([  4.50,   0.00,   0.00, 512.90, 883.79,   0.00], dtype=torch.float64)
# Target (missing):  tensor([   4.50,  147.17,  292.79,  512.90,  883.79, 1476.67],
#        dtype=torch.float64)
# Outputs (missing):  tensor([   2.40,  121.16,  266.31,  501.86,  863.52, 1418.93],
#        dtype=torch.float64, grad_fn=<AddBackward0>)
# Input (missing):  tensor([  0.00,  89.84, 172.87, 288.35, 456.56,   0.00], dtype=torch.float64)
# Target (missing):  tensor([  4.03,  89.84, 172.87, 288.35, 456.56, 755.36], dtype=torch.float64)
# Outputs (missing):  tensor([  2.28,  67.38, 139.65, 256.63, 435.12, 728.27], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([   4.64,  163.76,  345.78,  644.15, 1080.71,    0.00],
#        dtype=torch.float64)
# Target (missing):  tensor([   4.64,  163.76,  345.78,  644.15, 1080.71, 1841.24],
#        dtype=torch.float64)
# Outputs (missing):  tensor([   2.67,  143.95,  314.77,  603.34, 1042.95, 1746.77],
#        dtype=torch.float64, grad_fn=<AddBackward0>)
# Input (missing):  tensor([ 1.32, 12.25, 18.77,  0.00, 43.67, 44.24], dtype=torch.float64)
# Target (missing):  tensor([ 1.32, 12.25, 18.77,  7.06, 43.67, 44.24], dtype=torch.float64)
# Outputs (missing):  tensor([ 2.32, 20.59, 28.92, 34.06, 45.24, 37.54], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([  0.00,  83.85, 133.73, 209.86, 277.83, 412.03], dtype=torch.float64)
# Target (missing):  tensor([  3.71,  83.85, 133.73, 209.86, 277.83, 412.03], dtype=torch.float64)
# Outputs (missing):  tensor([  2.88,  52.23, 100.59, 169.34, 277.41, 411.93], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([ 1.19,  0.00, 31.25,  5.83, 29.39,  0.00], dtype=torch.float64)
# Target (missing):  tensor([ 1.19, 11.38, 31.25,  5.83, 29.39, 49.52], dtype=torch.float64)
# Outputs (missing):  tensor([ 2.27, 16.47, 22.68, 24.42, 27.61, 46.76], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Input (missing):  tensor([  0.00,  42.41,  46.89,  79.31, 139.49, 106.00], dtype=torch.float64)
# Target (missing): tensor([  2.83,  42.41,  46.89,  79.31, 139.49, 106.00], dtype=torch.float64)
# Outputs (missing):  tensor([  2.69,  34.75,  54.70,  81.45, 129.38, 115.77], dtype=torch.float64,
#        grad_fn=<AddBackward0>)
# Epoch 110 of 110, Train Loss: 53.63873, Overall: 518.30235

# %%
test_result = test(net)
# Out:
# 6, 174.55], dtype=torch.float64)
# Input (missing):  tensor([  1.09,   0.00,  16.51,   7.57,  33.98, 125.04], dtype=torch.float64)
# Target (missing):  tensor([  1.09,   7.01,  16.51,   7.57,  33.98, 125.04], dtype=torch.float64)
# Outputs (missing):  tensor([  2.46,  21.26,  34.87,  45.98,  63.77, 114.85], dtype=torch.float64)
# Input (missing):  tensor([  3.91,  77.70,   0.00,   0.00, 392.76, 686.32], dtype=torch.float64)
# Target (missing):  tensor([  3.91,  77.70, 148.86, 232.21, 392.76, 686.32], dtype=torch.float64)
# Outputs (missing):  tensor([  3.80,  69.16, 141.96, 248.29, 409.85, 677.41], dtype=torch.float64)
# Input:  tensor([  3.08,  32.00,  49.19,  72.84, 217.41, 171.61], dtype=torch.float64)
# Target:  tensor([  3.08,  32.00,  49.19,  72.84, 217.41, 171.61], dtype=torch.float64)
# Outputs:  tensor([  3.05,  47.69,  78.17, 124.81, 206.48, 188.56], dtype=torch.float64)
# Input (missing):  tensor([  4.52, 155.69, 294.85, 531.97, 926.51,   0.00], dtype=torch.float64)
# Target (missing):  tensor([   4.52,  155.69,  294.85,  531.97,  926.51, 1619.75],
#        dtype=torch.float64)
# Outputs (missing):  tensor([   5.45,  135.60,  286.54,  540.54,  926.14, 1540.75],
#        dtype=torch.float64)
# Input (missing):  tensor([ 2.21, 21.23, 30.17, 55.86, 61.04,  0.00], dtype=torch.float64)
# Target (missing):  tensor([  2.21,  21.23,  30.17,  55.86,  61.04, 145.88], dtype=torch.float64)
# Outputs (missing):  tensor([ 2.40, 20.37, 30.02, 37.93, 51.36, 71.93], dtype=torch.float64)
# Input (missing):  tensor([ 1.43, 22.37,  0.00, 64.87,  0.00, 59.25], dtype=torch.float64)
# Target (missing):  tensor([ 1.43, 22.37,  9.03, 64.87, 23.46, 59.25], dtype=torch.float64)
# Outputs (missing):  tensor([  2.40,  20.44,  32.74,  42.20,  58.40, 103.03], dtype=torch.float64)
# Input:  tensor([   4.63,  164.89,  330.78,  631.43, 1104.34, 1883.87],
#        dtype=torch.float64)
# Target:  tensor([   4.63,  164.89,  330.78,  631.43, 1104.34, 1883.87],
#        dtype=torch.float64)
# Outputs:  tensor([   6.50,  165.14,  363.42,  667.34, 1125.91, 1907.72],
#        dtype=torch.float64)
# Input:  tensor([   4.37,  125.68,  258.57,  429.68,  739.28, 1203.37],
#        dtype=torch.float64)
# Target:  tensor([   4.37,  125.68,  258.57,  429.68,  739.28, 1203.37],
#        dtype=torch.float64)
# Outputs:  tensor([   5.19,  118.08,  249.45,  449.20,  753.97, 1214.58],
#        dtype=torch.float64)
# Input (missing):  tensor([  3.22,  38.55,   0.00,  98.09, 178.23, 244.96], dtype=torch.float64)
# Target (missing):  tensor([  3.22,  38.55,  59.98,  98.09, 178.23, 244.96], dtype=torch.float64)
# Outputs (missing):  tensor([  2.97,  41.41,  72.74, 115.79, 186.16, 241.00], dtype=torch.float64)
# Input:  tensor([  2.61,  34.96,  27.00,  62.60, 122.05,  67.51], dtype=torch.float64)
# Target:  tensor([  2.61,  34.96,  27.00,  62.60, 122.05,  67.51], dtype=torch.float64)
# Outputs:  tensor([  2.66,  31.17,  47.99,  69.03, 107.28,  94.89], dtype=torch.float64)
# Input (missing):  tensor([  2.94,  29.99,   0.00,  66.70,  85.10, 199.15], dtype=torch.float64)
# Target (missing):  tensor([  2.94,  29.99,  45.25,  66.70,  85.10, 199.15], dtype=torch.float64)
# Outputs (missing):  tensor([  2.65,  26.85,  48.49,  71.29, 105.93, 192.47], dtype=torch.float64)
# Input (missing):  tensor([  3.70,  61.85, 111.56, 196.75,   0.00,   0.00], dtype=torch.float64)
# Target (missing):  tensor([  3.70,  61.85, 111.56, 196.75, 302.60, 443.94], dtype=torch.float64)
# Outputs (missing):  tensor([  3.28,  60.58, 118.29, 201.48, 340.91, 511.88], dtype=torch.float64)
# Input (missing):  tensor([  3.38,  44.83,  81.80, 119.25, 180.40,   0.00], dtype=torch.float64)
# Target (missing):  tensor([  3.38,  44.83,  81.80, 119.25, 180.40, 246.65], dtype=torch.float64)
# Outputs (missing):  tensor([  2.77,  34.98,  62.89, 103.96, 166.16, 274.26], dtype=torch.float64)
# Input (missing):  tensor([  3.95,   0.00, 157.95,   0.00, 442.02,   0.00], dtype=torch.float64)
# Target (missing):  tensor([  3.95,  86.90, 157.95, 241.29, 442.02, 597.37], dtype=torch.float64)
# Outputs (missing):  tensor([  3.83,  75.08, 147.33, 266.25, 449.39, 716.28], dtype=torch.float64)
# Input (missing):  tensor([  3.66,  60.47,   0.00, 161.61, 249.06, 406.49], dtype=torch.float64)
# Target (missing):  tensor([  3.66,  60.47,  98.38, 161.61, 249.06, 406.49], dtype=torch.float64)
# Outputs (missing):  tensor([  3.27,  50.42,  96.78, 161.54, 262.18, 402.88], dtype=torch.float64)
# Input (missing):  tensor([ 1.23, 10.54,  6.60, 21.46,  0.00,  0.00], dtype=torch.float64)
# Target (missing):  tensor([  1.23,  10.54,   6.60,  21.46,  24.75, 132.63], dtype=torch.float64)
# Outputs (missing):  tensor([ 2.41, 18.84, 27.07, 29.12, 34.69, 39.32], dtype=torch.float64)
# Input (missing):  tensor([ 1.42, 20.12,  0.00,  0.00,  0.00,  0.00], dtype=torch.float64)
# Target (missing):  tensor([ 1.42, 20.12,  7.26, 33.42, 33.45, 13.75], dtype=torch.float64)
# Outputs (missing):  tensor([ 2.30, 16.15, 22.21, 22.86, 24.46, 42.92], dtype=torch.float64)
# Input:  tensor([  2.08,  27.13,  31.92,  43.82,  46.82, 165.52], dtype=torch.float64)
# Target:  tensor([  2.08,  27.13,  31.92,  43.82,  46.82, 165.52], dtype=torch.float64)
# Outputs:  tensor([  2.55,  24.56,  42.57,  60.42,  88.62, 157.89], dtype=torch.float64)
# Input (missing):  tensor([  3.59,  57.12,   0.00, 162.85, 271.26, 331.82], dtype=torch.float64)
# Target (missing):  tensor([  3.59,  57.12, 104.53, 162.85, 271.26, 331.82], dtype=torch.float64)
# Outputs (missing):  tensor([  3.34,  56.64, 100.88, 167.73, 278.24, 331.14], dtype=torch.float64)
# Input (missing): tensor([ 1.04,  0.00, 31.25, 29.63, 58.05,  0.00], dtype=torch.float64)
# Target (missing):  tensor([  1.04,  19.94,  31.25,  29.63,  58.05, 130.74], dtype=torch.float64)
# Outputs (missing):  tensor([ 2.40, 19.97, 29.87, 37.78, 50.76, 77.72], dtype=torch.float64)
# Input (missing):  tensor([  3.24,  49.01,   0.00, 135.50, 131.93, 258.68], dtype=torch.float64)
# Target (missing):  tensor([  3.24,  49.01,  63.76, 135.50, 131.93, 258.68], dtype=torch.float64)
# Outputs (missing):  tensor([  2.80,  32.70,  61.23,  95.55, 147.46, 257.44], dtype=torch.float64)
# Input (missing):  tensor([  0.00,  38.33,  75.76, 100.53, 111.55, 269.11], dtype=torch.float64)
# Target (missing):  tensor([  3.10,  38.33,  75.76, 100.53, 111.55, 269.11], dtype=torch.float64)
# Outputs (missing):  tensor([  2.78,  32.08,  60.45,  93.87, 145.44, 259.01], dtype=torch.float64)
# Input:  tensor([ 1.97, 24.78, 19.81, 56.97, 33.75, 37.69], dtype=torch.float64)
# Target:  tensor([ 1.97, 24.78, 19.81, 56.97, 33.75, 37.69], dtype=torch.float64)
# Outputs:  tensor([ 2.40, 19.85, 27.70, 31.46, 40.13, 35.25], dtype=torch.float64)
# Input (missing):  tensor([   4.88,  227.82,  473.11,    0.00,    0.00, 2678.21],
#        dtype=torch.float64)
# Target (missing):  tensor([   4.88,  227.82,  473.11,  892.99, 1583.89, 2678.21],
#        dtype=torch.float64)
# Outputs (missing):  tensor([   7.47,  236.77,  514.25,  944.12, 1648.40, 2687.02],
#        dtype=torch.float64)
# Input (missing):  tensor([ 1.47,  0.00, 21.34, 22.23,  0.00,  0.00], dtype=torch.float64)
# Target (missing):  tensor([ 1.47, 12.03, 21.34, 22.23, 26.67, 41.61], dtype=torch.float64)
# Outputs (missing):  tensor([ 2.38, 18.01, 25.51, 26.74, 30.79, 37.19], dtype=torch.float64)
# Input (missing):  tensor([  3.29,   0.00,  61.68, 109.68,   0.00, 206.84], dtype=torch.float64)
# Target (missing):  tensor([  3.29,  39.27,  61.68, 109.68, 166.56, 206.84], dtype=torch.float64)
# Outputs (missing):  tensor([  2.62,  29.29,  52.20,  78.43, 122.04, 205.28], dtype=torch.float64)
# Input (missing):  tensor([  3.62,   0.00, 100.28, 157.17, 260.77, 390.95], dtype=torch.float64)
# Target (missing):  tensor([  3.62,  58.72, 100.28, 157.17, 260.77, 390.95], dtype=torch.float64)
# Outputs (missing):  tensor([  3.28,  51.33,  97.02, 161.80, 263.68, 387.50], dtype=torch.float64)
# Input:  tensor([  3.42,  44.03,  88.69, 130.98, 212.52, 313.71], dtype=torch.float64)
# Target:  tensor([  3.42,  44.03,  88.69, 130.98, 212.52, 313.71], dtype=torch.float64)
# Outputs:  tensor([  3.11,  45.66,  83.93, 137.01, 221.46, 314.74], dtype=torch.float64)
# Input (missing):  tensor([  4.22,   0.00, 200.55, 374.69, 578.44, 903.10], dtype=torch.float64)
# Target (missing):  tensor([  4.22, 105.62, 200.55, 374.69, 578.44, 903.10], dtype=torch.float64)
# Outputs (missing):  tensor([  4.52,  94.85, 194.79, 345.71, 577.89, 901.49], dtype=torch.float64)
# Input:  tensor([  4.20, 107.38, 198.82, 357.51, 617.37, 974.96], dtype=torch.float64)
# Target:  tensor([  4.20, 107.38, 198.82, 357.51, 617.37, 974.96], dtype=torch.float64)
# Outputs:  tensor([  4.73, 102.39, 211.18, 376.39, 630.55, 982.13], dtype=torch.float64)
# Input (missing):  tensor([ 1.21,  0.00, 13.63,  5.66,  0.00, 97.70], dtype=torch.float64)
# Target (missing):  tensor([ 1.21,  9.66, 13.63,  5.66, 25.25, 97.70], dtype=torch.float64)
# Outputs (missing):  tensor([ 2.40, 19.83, 31.05, 38.82, 52.28, 91.32], dtype=torch.float64)
# Input:  tensor([  2.64,  29.21,  38.68,  52.25, 111.60,  85.68], dtype=torch.float64)
# Target:  tensor([  2.64,  29.21,  38.68,  52.25, 111.60,  85.68], dtype=torch.float64)
# Outputs:  tensor([  2.66,  31.40,  48.40,  69.73, 108.50,  95.58], dtype=torch.float64)
# Input (missing):  tensor([ 0.00,  4.60,  4.74,  5.11, 46.06, 13.73], dtype=torch.float64)
# Target (missing):  tensor([ 1.07,  4.60,  4.74,  5.11, 46.06, 13.73], dtype=torch.float64)
# Outputs (missing):  tensor([ 2.36, 18.64, 24.98, 26.65, 32.11, 22.90], dtype=torch.float64)
# Input:  tensor([  4.18,  99.27, 203.95, 364.31, 539.02, 872.24], dtype=torch.float64)
# Target:  tensor([  4.18,  99.27, 203.95, 364.31, 539.02, 872.24], dtype=torch.float64)
# Outputs:  tensor([  4.42,  90.66, 187.42, 331.99, 553.31, 881.06], dtype=torch.float64)
# Input (missing):  tensor([ 1.87,  9.42,  0.00, 27.55, 41.79,  0.00], dtype=torch.float64)
# Target (missing):  tensor([ 1.87,  9.42, 19.03, 27.55, 41.79, 51.93], dtype=torch.float64)
# Outputs (missing):  tensor([ 2.34, 18.00, 24.72, 27.22, 32.75, 39.02], dtype=torch.float64)
# Input:  tensor([ 2.39, 23.65, 21.68, 41.83, 99.36, 54.48], dtype=torch.float64)
# Target:  tensor([ 2.39, 23.65, 21.68, 41.83, 99.36, 54.48], dtype=torch.float64)
# Outputs:  tensor([ 2.58, 27.78, 41.74, 57.53, 86.89, 75.15], dtype=torch.float64)
# Input:  tensor([ 1.61,  9.10, 22.77, 13.98, 77.00, 38.23], dtype=torch.float64)
# Target:  tensor([ 1.61,  9.10, 22.77, 13.98, 77.00, 38.23], dtype=torch.float64)
# Outputs:  tensor([ 2.48, 23.95, 34.69, 44.57, 63.93, 53.12], dtype=torch.float64)
# Input (missing):  tensor([  1.63,   0.00,  10.53,  12.27, 106.24, 157.67], dtype=torch.float64)
# Target (missing):  tensor([  1.63,  21.53,  10.53,  12.27, 106.24, 157.67], dtype=torch.float64)
# Outputs (missing):  tensor([  2.65,  29.01,  48.45,  70.83, 107.46, 147.90], dtype=torch.float64)
# Input (missing):  tensor([  3.56,  56.48,   0.00, 175.51,   0.00, 423.03], dtype=torch.float64)
# Target (missing):  tensor([  3.56,  56.48,  87.52, 175.51, 258.53, 423.03], dtype=torch.float64)
# Outputs (missing):  tensor([  3.05,  47.29,  92.41, 153.78, 254.69, 421.88], dtype=torch.float64)
# Input (missing):  tensor([  4.16,   0.00, 195.89, 324.11, 526.55,   0.00], dtype=torch.float64)
# Target (missing):  tensor([  4.16,  96.95, 195.89, 324.11, 526.55, 928.84], dtype=torch.float64)
# Outputs (missing):  tensor([  4.06,  81.33, 169.85, 312.24, 527.63, 896.22], dtype=torch.float64)
# Input:  tensor([  2.69,  22.06,  37.29,  63.15, 102.17, 221.80], dtype=torch.float64)
# Target:  tensor([  2.69,  22.06,  37.29,  63.15, 102.17, 221.80], dtype=torch.float64)
# Outputs:  tensor([  2.70,  28.63,  52.74,  79.18, 119.17, 216.23], dtype=torch.float64)
# Input (missing):  tensor([   4.73,    0.00,    0.00,  707.80, 1293.62, 2049.83],
#        dtype=torch.float64)
# Target (missing):  tensor([   4.73,  182.87,  377.50,  707.80, 1293.62, 2049.83],
#        dtype=torch.float64)
# Outputs (missing):  tensor([   7.29,  193.71,  413.52,  757.45, 1283.92, 2024.46],
#        dtype=torch.float64)
# Input:  tensor([   4.91,  222.13,  470.00,  934.23, 1613.31, 2763.54],
#        dtype=torch.float64)
# Target:  tensor([   4.91,  222.13,  470.00,  934.23, 1613.31, 2763.54],
#        dtype=torch.float64)
# Outputs:  tensor([   8.40,  233.23,  521.65,  967.78, 1639.43, 2802.28],
#        dtype=torch.float64)
# Input (missing):  tensor([  2.43,  20.15,  44.66,   0.00,  68.18, 199.51], dtype=torch.float64)
# Target (missing):  tensor([  2.43,  20.15,  44.66, 103.54,  68.18, 199.51], dtype=torch.float64)
# Outputs (missing):  tensor([  2.63,  26.79,  47.92,  70.46, 105.59, 188.51], dtype=torch.float64)
# Input (missing):  tensor([  1.78,   9.87,  26.89,  13.17,   0.00, 193.41], dtype=torch.float64)
# Target (missing):  tensor([  1.78,   9.87,  26.89,  13.17,  76.17, 193.41], dtype=torch.float64)
# Outputs (missing):  tensor([  2.59,  27.88,  49.01,  72.46, 111.55, 187.91], dtype=torch.float64)
# Input (missing):  tensor([  3.68,   0.00,   0.00, 171.96, 255.08, 378.32], dtype=torch.float64)
# Target (missing):  tensor([  3.68,  59.79, 131.74, 171.96, 255.08, 378.32], dtype=torch.float64)
# Outputs (missing):  tensor([  3.26,  50.98,  95.33, 158.48, 258.52, 370.03], dtype=torch.float64)
# Input:  tensor([  3.35,  46.69,  72.76, 132.73, 198.04, 297.26], dtype=torch.float64)
# Target:  tensor([  3.35,  46.69,  72.76, 132.73, 198.04, 297.26], dtype=torch.float64)
# Outputs:  tensor([  3.06,  43.55,  79.75, 129.20, 207.79, 297.88], dtype=torch.float64)
# Input (missing):  tensor([ 0.00,  0.00, 27.25, 33.07, 29.58, 25.76], dtype=torch.float64)
# Target (missing):  tensor([ 1.31,  7.62, 27.25, 33.07, 29.58, 25.76], dtype=torch.float64)
# Outputs (missing):  tensor([ 2.34, 17.89, 23.74, 24.22, 27.60, 19.49], dtype=torch.float64)
# Input (missing):  tensor([   4.43,  140.84,  259.24,  496.27,    0.00, 1277.60],
#        dtype=torch.float64)
# Target (missing):  tensor([   4.43,  140.84,  259.24,  496.27,  868.38, 1277.60],
#        dtype=torch.float64)
# Outputs (missing):  tensor([   4.75,  120.29,  254.99,  458.38,  791.88, 1295.26],
#        dtype=torch.float64)
# Input (missing):  tensor([ 1.38,  8.04, 18.11, 19.48,  0.00, 52.31], dtype=torch.float64)
# Target (missing):  tensor([ 1.38,  8.04, 18.11, 19.48, 33.67, 52.31], dtype=torch.float64)
# Outputs (missing):  tensor([ 2.31, 16.16, 22.91, 23.56, 25.32, 47.77], dtype=torch.float64)
# Input (missing):  tensor([ 0.00,  6.63, 20.94, 25.27, 96.36, 17.22], dtype=torch.float64)
# Target (missing):  tensor([ 1.01,  6.63, 20.94, 25.27, 96.36, 17.22], dtype=torch.float64)
# Outputs (missing):  tensor([ 2.48, 23.73, 34.29, 43.94, 62.85, 52.51], dtype=torch.float64)
# Input (missing):  tensor([  3.19,   0.00,  77.89,  85.91, 176.85, 234.82], dtype=torch.float64)
# Target (missing):  tensor([  3.19,  33.65,  77.89,  85.91, 176.85, 234.82], dtype=torch.float64)
# Outputs (missing):  tensor([  2.94,  40.32,  70.48, 111.63, 178.97, 231.25], dtype=torch.float64)
# Input:  tensor([ 2.74, 29.60, 40.15, 99.01, 85.53, 82.87], dtype=torch.float64)
# Target:  tensor([ 2.74, 29.60, 40.15, 99.01, 85.53, 82.87], dtype=torch.float64)
# Outputs:  tensor([ 2.60, 28.53, 43.51, 60.56, 91.85, 83.31], dtype=torch.float64)
# Input (missing):  tensor([  0.00,  29.69,   0.00,  59.71,  77.70, 140.72], dtype=torch.float64)
# Target (missing):  tensor([  2.68,  29.69,  28.85,  59.71,  77.70, 140.72], dtype=torch.float64)
# Outputs (missing):  tensor([  2.55,  24.22,  40.64,  56.40,  81.09, 133.47], dtype=torch.float64)
# Input (missing):  tensor([  3.73,  63.72, 121.23, 214.75, 287.67,   0.00], dtype=torch.float64)
# Target (missing):  tensor([  3.73,  63.72, 121.23, 214.75, 287.67, 537.70], dtype=torch.float64)
# Outputs (missing):  tensor([  3.14,  48.82,  94.53, 166.05, 274.09, 459.49], dtype=torch.float64)
# Input (missing):  tensor([   4.59,  160.46,  338.67,  621.89,    0.00, 1761.35],
#        dtype=torch.float64)
# Target (missing):  tensor([   4.59,  160.46,  338.67,  621.89, 1002.99, 1761.35],
#        dtype=torch.float64)
# Outputs (missing):  tensor([   5.70,  161.04,  345.70,  628.33, 1091.71, 1782.26],
#        dtype=torch.float64)
# Input:  tensor([   4.93,  239.56,  501.58,  943.07, 1713.62, 2818.24],
#        dtype=torch.float64)
# Target:  tensor([   4.93,  239.56,  501.58,  943.07, 1713.62, 2818.24],
#        dtype=torch.float64)
# Outputs:  tensor([   8.90,  250.98,  551.25, 1019.54, 1730.11, 2846.37],
#        dtype=torch.float64)
# Input (missing):  tensor([  0.00, 186.23,   0.00, 715.39,   0.00,   0.00], dtype=torch.float64)
# Target (missing):  tensor([   4.72,  186.23,  384.16,  715.39, 1286.18, 1992.73],
#        dtype=torch.float64)
# Outputs (missing):  tensor([   6.18,  185.77,  392.33,  719.32, 1256.40, 1913.56],
#        dtype=torch.float64)
# Input (missing):  tensor([  2.45,   0.00,  28.44,   0.00,  55.41, 183.58], dtype=torch.float64)
# Target (missing):  tensor([  2.45,  23.26,  28.44,  36.84,  55.41, 183.58], dtype=torch.float64)
# Outputs (missing):  tensor([  2.58,  25.61,  45.02,  65.02,  96.52, 171.61], dtype=torch.float64)
# Input (missing):  tensor([  1.99,  12.52,   0.00,   0.00, 111.54,  75.35], dtype=torch.float64)
# Target (missing):  tensor([  1.99,  12.52,  13.31,  26.69, 111.54,  75.35], dtype=torch.float64)
# Outputs (missing):  tensor([ 2.62, 29.96, 45.60, 64.77, 99.92, 86.43], dtype=torch.float64)
# Input:  tensor([ 1.98,  9.95, 27.82, 85.61, 27.10, 27.36], dtype=torch.float64)
# Target:  tensor([ 1.98,  9.95, 27.82, 85.61, 27.10, 27.36], dtype=torch.float64)
# Outputs:  tensor([ 2.40, 18.89, 26.31, 28.12, 33.51, 30.12], dtype=torch.float64)
# Input (missing):  tensor([ 1.64,  7.66,  0.00, 15.85, 35.42, 31.47], dtype=torch.float64)
# Target (missing):  tensor([ 1.64,  7.66, 15.64, 15.85, 35.42, 31.47], dtype=torch.float64)
# Outputs (missing):  tensor([ 2.38, 19.49, 26.55, 29.44, 36.99, 27.32], dtype=torch.float64)
# Input (missing):  tensor([  3.89,  83.50, 167.86,   0.00, 356.92, 586.98], dtype=torch.float64)
# Target (missing):  tensor([  3.89,  83.50, 167.86, 221.19, 356.92, 586.98], dtype=torch.float64)
# Outputs (missing):  tensor([  3.69,  65.16, 130.34, 225.28, 371.08, 587.08], dtype=torch.float64)
# Input:  tensor([ 2.07, 16.45, 37.81, 49.62, 44.41, 74.87], dtype=torch.float64)
# Target:  tensor([ 2.07, 16.45, 37.81, 49.62, 44.41, 74.87], dtype=torch.float64)
# Outputs:  tensor([ 2.44, 20.54, 31.12, 38.21, 50.64, 71.11], dtype=torch.float64)
# Input:  tensor([   4.79,  200.86,  404.77,  792.15, 1360.27, 2318.21],
#        dtype=torch.float64)
# Target:  tensor([   4.79,  200.86,  404.77,  792.15, 1360.27, 2318.21],
#        dtype=torch.float64)
# Outputs:  tensor([   7.47,  199.82,  443.19,  818.43, 1384.28, 2349.79],
#        dtype=torch.float64)
# Input (missing):  tensor([ 1.75,  0.00, 24.46, 39.97, 39.51, 98.51], dtype=torch.float64)
# Target (missing):  tensor([ 1.75, 13.00, 24.46, 39.97, 39.51, 98.51], dtype=torch.float64)
# Outputs (missing):  tensor([ 2.42, 19.17, 30.39, 37.52, 48.48, 91.30], dtype=torch.float64)
# Input (missing):  tensor([   4.48,  142.45,  302.23,  530.98,    0.00, 1433.52],
#        dtype=torch.float64)
# Target (missing):  tensor([   4.48,  142.45,  302.23,  530.98,  864.23, 1433.52],
#        dtype=torch.float64)
# Outputs (missing):  tensor([   5.05,  133.47,  284.32,  513.33,  888.85, 1452.65],
#        dtype=torch.float64)
# Input (missing):  tensor([   4.53,  151.20,  317.93,    0.00,  937.53, 1517.68],
#        dtype=torch.float64)
# Target (missing):  tensor([   4.53,  151.20,  317.93,  548.08,  937.53, 1517.68],
#        dtype=torch.float64)
# Outputs (missing):  tensor([   5.94,  146.09,  309.80,  563.66,  951.45, 1516.02],
#        dtype=torch.float64)
# Input (missing):  tensor([  0.00,  43.08,  54.84,  74.03, 122.71, 187.14], dtype=torch.float64)
# Target (missing):  tensor([  3.05,  43.08,  54.84,  74.03, 122.71, 187.14], dtype=torch.float64)
# Outputs (missing):  tensor([  2.73,  31.28,  54.27,  81.65, 125.42, 183.91], dtype=torch.float64)
# Input (missing):  tensor([   4.67,  172.66,    0.00,    0.00, 1127.02, 1922.74],
#        dtype=torch.float64)
# Target (missing):  tensor([   4.67,  172.66,  347.67,  658.27, 1127.02, 1922.74],
#        dtype=torch.float64)
# Outputs (missing):  tensor([   6.59,  170.12,  370.07,  680.47, 1150.65, 1907.53],
#        dtype=torch.float64)
# Test Loss: 1601.415

# %%
predicted = net(x_test.double())
predicted = predicted.detach().numpy()
predicted
# Out:
# tensor([[    4.31,    89.27,   177.18,   311.61,   522.34,   759.94],
#         [    2.62,    26.72,    45.57,    65.55,    97.06,   152.96],
#         [    2.62,    26.18,    46.79,    68.22,   101.11,   182.92],
#         [    2.54,    24.70,    42.56,    60.39,    89.11,   156.34],
#         [    3.05,    43.91,    78.88,   127.40,   205.71,   277.87],
#         [    4.37,    90.27,   182.02,   321.04,   536.96,   809.33],
#         [    2.62,    28.06,    45.91,    65.91,    99.23,   130.38],
#         [    4.05,    77.88,   157.56,   275.87,   458.11,   714.49],
#         [    3.14,    58.51,   115.73,   200.80,   341.90,   541.83],
#         [    2.32,    15.94,    22.58,    22.95,    23.95,    46.83],
#         [    2.45,    21.40,    32.10,    39.89,    54.03,    67.18],
#         [    2.33,    17.33,    22.72,    22.37,    24.32,    16.74],
#         [    2.31,    16.85,    22.90,    24.21,    27.29,    38.95],
#         [    2.48,    23.27,    36.46,    50.32,    72.74,   106.40],
#         [    2.55,    26.23,    45.43,    65.75,    99.56,   169.12],
#         [    2.56,    26.91,    40.38,    54.95,    82.10,    72.72],
#         [    8.53,   238.47,   533.30,   990.22,  1678.24,  2865.45],
#         [    2.55,    27.96,    46.74,    70.34,   109.67,   171.54],
#         [    2.49,    22.44,    35.16,    45.92,    64.03,    91.03],
#         [    3.38,    53.34,   104.86,   176.92,   287.57,   459.41],
#         [    2.83,    34.51,    65.55,   103.51,   163.10,   285.31],
#         [    3.51,    58.66,   114.98,   195.63,   320.53,   494.94],
#         [    2.43,    21.63,    30.47,    36.77,    50.03,    40.14],
#         [    5.13,   118.58,   242.04,   433.55,   731.25,  1092.19],
#         [    2.42,    20.79,    33.29,    43.00,    59.51,   103.77],
#         [    2.53,    24.31,    38.40,    51.71,    74.36,    98.12],
#         [    4.70,   100.75,   214.77,   385.42,   643.87,  1077.17],
#         [    2.32,    17.14,    23.53,    25.43,    29.39,    42.35],
#         [    7.18,   224.54,   487.22,   893.51,  1559.20,  2543.15],
#         [    2.59,    27.90,    46.55,    71.16,   109.06,   174.55],
#         [    2.46,    21.26,    34.87,    45.98,    63.77,   114.85],
#         [    3.80,    69.16,   141.96,   248.29,   409.85,   677.41],
#         [    3.05,    47.69,    78.17,   124.81,   206.48,   188.56],
#         [    5.45,   135.60,   286.54,   540.54,   926.14,  1540.75],
#         [    2.40,    20.37,    30.02,    37.93,    51.36,    71.93],
#         [    2.40,    20.44,    32.74,    42.20,    58.40,   103.03],
#         [    6.50,   165.14,   363.42,   667.34,  1125.91,  1907.72],
#         [    5.19,   118.08,   249.45,   449.20,   753.97,  1214.58],
#         [    2.97,    41.41,    72.74,   115.79,   186.16,   241.00],
#         [    2.66,    31.17,    47.99,    69.03,   107.28,    94.89],
#         [    2.65,    26.85,    48.49,    71.29,   105.93,   192.47],
#         [    3.28,    60.58,   118.29,   201.48,   340.91,   511.88],
#         [    2.77,    34.98,    62.89,   103.96,   166.16,   274.26],
#         [    3.83,    75.08,   147.33,   266.25,   449.39,   716.28],
#         [    3.27,    50.42,    96.78,   161.54,   262.18,   402.88],
#         [    2.41,    18.84,    27.07,    29.12,    34.69,    39.32],
#         [    2.30,    16.15,    22.21,    22.86,    24.46,    42.92],
#         [    2.55,    24.56,    42.57,    60.42,    88.62,   157.89],
#         [    3.34,    56.64,   100.88,   167.73,   278.24,   331.14],
#         [    2.40,    19.97,    29.87,    37.78,    50.76,    77.72],
#         [    2.80,    32.70,    61.23,    95.55,   147.46,   257.44],
#         [    2.78,    32.08,    60.45,    93.87,   145.44,   259.01],
#         [    2.40,    19.85,    27.70,    31.46,    40.13,    35.25],
#         [    7.47,   236.77,   514.25,   944.12,  1648.40,  2687.02],
#         [    2.38,    18.01,    25.51,    26.74,    30.79,    37.19],
#         [    2.62,    29.29,    52.20,    78.43,   122.04,   205.28],
#         [    3.28,    51.33,    97.02,   161.80,   263.68,   387.50],
#         [    3.11,    45.66,    83.93,   137.01,   221.46,   314.74],
#         [    4.52,    94.85,   194.79,   345.71,   577.89,   901.49],
#         [    4.73,   102.39,   211.18,   376.39,   630.55,   982.13],
#         [    2.40,    19.83,    31.05,    38.82,    52.28,    91.32],
#         [    2.66,    31.40,    48.40,    69.73,   108.50,    95.58],
#         [    2.36,    18.64,    24.98,    26.65,    32.11,    22.90],
#         [    4.42,    90.66,   187.42,   331.99,   553.31,   881.06],
#         [    2.34,    18.00,    24.72,    27.22,    32.75,    39.02],
#         [    2.58,    27.78,    41.74,    57.53,    86.89,    75.15],
#         [    2.48,    23.95,    34.69,    44.57,    63.93,    53.12],
#         [    2.65,    29.01,    48.45,    70.83,   107.46,   147.90],
#         [    3.05,    47.29,    92.41,   153.78,   254.69,   421.88],
#         [    4.06,    81.33,   169.85,   312.24,   527.63,   896.22],
#         [    2.70,    28.63,    52.74,    79.18,   119.17,   216.23],
#         [    7.29,   193.71,   413.52,   757.45,  1283.92,  2024.46],
#         [    8.40,   233.23,   521.65,   967.78,  1639.43,  2802.28],
#         [    2.63,    26.79,    47.92,    70.46,   105.59,   188.51],
#         [    2.59,    27.88,    49.01,    72.46,   111.55,   187.91],
#         [    3.26,    50.98,    95.33,   158.48,   258.52,   370.03],
#         [    3.06,    43.55,    79.75,   129.20,   207.79,   297.88],
#         [    2.34,    17.89,    23.74,    24.22,    27.60,    19.49],
#         [    4.75,   120.29,   254.99,   458.38,   791.88,  1295.26],
#         [    2.31,    16.16,    22.91,    23.56,    25.32,    47.77],
#         [    2.48,    23.73,    34.29,    43.94,    62.85,    52.51],
#         [    2.94,    40.32,    70.48,   111.63,   178.97,   231.25],
#         [    2.60,    28.53,    43.51,    60.56,    91.85,    83.31],
#         [    2.55,    24.22,    40.64,    56.40,    81.09,   133.47],
#         [    3.14,    48.82,    94.53,   166.05,   274.09,   459.49],
#         [    5.70,   161.04,   345.70,   628.33,  1091.71,  1782.26],
#         [    8.90,   250.98,   551.25,  1019.54,  1730.11,  2846.37],
#         [    6.18,   185.77,   392.33,   719.32,  1256.40,  1913.56],
#         [    2.58,    25.61,    45.02,    65.02,    96.52,   171.61],
#         [    2.62,    29.96,    45.60,    64.77,    99.92,    86.43],
#         [    2.40,    18.89,    26.31,    28.12,    33.51,    30.12],
#         [    2.38,    19.49,    26.55,    29.44,    36.99,    27.32],
#         [    3.69,    65.16,   130.34,   225.28,   371.08,   587.08],
#         [    2.44,    20.54,    31.12,    38.21,    50.64,    71.11],
#         [    7.47,   199.82,   443.19,   818.43,  1384.28,  2349.79],
#         [    2.42,    19.17,    30.39,    37.52,    48.48,    91.30],
#         [    5.05,   133.47,   284.32,   513.33,   888.85,  1452.65],
#         [    5.94,   146.09,   309.80,   563.66,   951.45,  1516.02],
#         [    2.73,    31.28,    54.27,    81.65,   125.42,   183.91],
#         [    6.59,   170.12,   370.07,   680.47,  1150.65,  1907.53]],
#        dtype=torch.float64, grad_fn=<AddmmBackward>)

# %%
# Plot in blue color the predicted adata and in green color the
# actual data to verify visually the accuracy of the model.
plt.plot(predicted)
# Out:
# [<matplotlib.lines.Line2D at 0x1e7e6d062b0>,
#  <matplotlib.lines.Line2D at 0x1e7e6d063c8>,
#  <matplotlib.lines.Line2D at 0x1e7e6d06518>,
#  <matplotlib.lines.Line2D at 0x1e7e6d06668>,
#  <matplotlib.lines.Line2D at 0x1e7e6d067b8>,
#  <matplotlib.lines.Line2D at 0x1e7e6d06908>]

# %%
plt.plot(y_test)
# Out:
# [<matplotlib.lines.Line2D at 0x1e7ea764c50>,
#  <matplotlib.lines.Line2D at 0x1e7ea764d68>,
#  <matplotlib.lines.Line2D at 0x1e7ea764eb8>,
#  <matplotlib.lines.Line2D at 0x1e7ea76f048>,
#  <matplotlib.lines.Line2D at 0x1e7ea76f198>,
#  <matplotlib.lines.Line2D at 0x1e7ea76f2e8>]

# %%
plt.plot(predicted[:, 1], color='green')
plt.plot(y_test[:, 1], color='blue')
plt.show()

# %%
plt.scatter(y_test[:,0], predicted[:, 2], color='green')
plt.scatter(y_test[:,0], y_test[:, 2], color='blue')
plt.show()

# %%
plt.plot(predicted[:, 3], color='green')
plt.plot(y_test[:, 3], color='blue')
plt.show()

# %%
plt.scatter(y_test[:,0], predicted[:, 2], color='green')
plt.scatter(y_test[:,0], y_test[:, 2], color='blue')
#plt.fill_between(y_test[:,0], predicted[:, 2], y_test[:, 2], color='grey', alpha=0.5)
plt.show()
